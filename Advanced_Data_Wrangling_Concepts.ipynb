# %% [markdown]
# # **👨🏻‍🎓 Learning Objective 👨🏻‍🎓**

# %% [markdown]
# ### **Introduction**

# %% [markdown]
# 👋 Hello students! Are you ready to take your data wrangling skills to the next level? Today, we'll introduce you to advanced data wrangling concepts in Python.
#
# 🧐 But first, what is data wrangling? Data wrangling transforms and cleans raw data into a format that is easier to work with and analyze. This includes filtering, transforming, merging, and aggregating data.
#
# 🐍 In Python, Pandas is a popular library used for data wrangling. Let's take a look at some advanced data wrangling concepts you can use in Pandas.
#
# 📉 Handling missing data: Pandas provides functions to handle missing data, such as fillna(), dropna(), and interpolate().
#
# 📊 Grouping and aggregation: You can group data based on specific criteria using the groupby() function, and perform aggregation operations such as mean(), sum(), and count() on the grouped data.
#
# 📏 Reshaping data: Pandas allows you to reshape data using functions such as pivot(), melt(), stack(), and unstack().
#
# 📝 Merging and joining data: You can merge and join data from different sources using functions such as merge() and join().
#
# 🔍 Filtering data: You can filter data based on specific criteria using functions such as loc() and query().
#
# 📈 Time-series data analysis: Pandas provides functions to handle time-series data, such as resample() and rolling().
#
# 📝 These advanced data wrangling concepts are essential for any data analyst or scientist, and can help you manipulate and transform data for analysis and visualization.
#
# 🚀 So, are you ready to take your data wrangling skills to the next level with these advanced concepts in Python? Let's dive in! 🐍

# %% [markdown]
# ### **Primary Goals**

# %% [markdown]
# 🎯 By the end of this lesson, you will be able to:
#
# 📉 Handle missing data using Pandas functions such as fillna(), dropna(), and interpolate().
#
# 📊 Group data based on specific criteria using the groupby() function, and perform aggregation operations such as mean(), sum(), and count() on the grouped data.
#
# 📏 Reshape data using Pandas functions such as pivot(), melt(), stack(), and unstack().
#
# 📝 Merge and join data from different sources using Pandas functions such as merge() and join().
#
# 🔍 Filter data based on specific criteria using Pandas functions such as loc() and query().
#
# 📈 Analyze time-series data using Pandas functions such as resample() and rolling().
#
# 📝 These are essential skills for any data analyst or scientist, and mastering them will allow you to transform and manipulate data with ease, and prepare it
# for further analysis and visualization.
#
# 🚀 Are you ready to take on these advanced data wrangling concepts in Python? Let's get started! 🐍

# %% [markdown]
# #**📖Learning Material📖**

# %% [markdown]
# 👋 Hey there!
#
# 👨‍🏫 Today's lesson is  about Data Wrangling.

# %% [markdown]
# ![popp.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# 👋 Welcome students! Today's lesson is all about exploring few of the most important operations you can perform in pandas 🐼, a popular Python library used for data manipulation and analysis 📊. We'll be focusing on apply and lambda statements 📝, merging and joining data frames 🤝, and group by operations 🔍.
#
# By learning these concepts, you'll be able to better understand how to manipulate and analyze data sets 💻, which is an essential skill for data scientists and analysts 🧐. Throughout the lesson, you'll have the opportunity to apply these operations in practice 🙌, as we'll be working with a variety of data sets to help you understand how to use these concepts in real-world situations 🌎.

# %% [markdown]
# ### Let us understand more of this  by implementation on IMDb dataset.

# %%
# Importing  pandas and numpy

import pandas as pd
import numpy as np

# %%
# #Connecting Google Drive with the Colab
# from google.colab import drive
# drive.mount('/content/drive')

# %%
file_path = 'imdb_data (1).csv'  ##Paste the filepath to imdb dataset you downloaded previously.
imdb_df=pd.read_csv(file_path)

# %%
imdb_df.head()
# Out:
#    id                              belongs_to_collection    budget  \
# 0   1  [{'id': 313576, 'name': 'Hot Tub Time Machine ...  14000000
# 1   2  [{'id': 107674, 'name': 'The Princess Diaries ...  40000000
# 2   3                                                NaN   3300000
# 3   4                                                NaN   1200000
# 4   5                                                NaN         0
#
#                                               genres  \
# 0                     [{'id': 35, 'name': 'Comedy'}]
# 1  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 2                      [{'id': 18, 'name': 'Drama'}]
# 3  [{'id': 53, 'name': 'Thriller'}, {'id': 18, 'n...
# 4  [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...
#
#                             homepage    imdb_id original_language  \
# 0                                NaN  tt2637294                en
# 1                                NaN  tt0368933                en
# 2  http://sonyclassics.com/whiplash/  tt2582802                en
# 3         http://kahaanithefilm.com/  tt1821480                hi
# 4                                NaN  tt1380152                ko
#
#                              original_title  \
# 0                    Hot Tub Time Machine 2
# 1  The Princess Diaries 2: Royal Engagement
# 2                                  Whiplash
# 3                                   Kahaani
# 4                                      마린보이
#
#                                             overview  popularity  ...  \
# 0  When Lou, who has become the "father of the In...    6.575393  ...
# 1  Mia Thermopolis is now a college graduate and ...    8.248895  ...
# 2  Under the direction of a ruthless instructor, ...   64.299990  ...
# 3  Vidya Bagchi (Vidya Balan) arrives in Kolkata ...    3.174936  ...
# 4  Marine Boy is the story of a former national s...    1.148070  ...
#
#   release_date runtime                                   spoken_languages  \
# 0      2/20/15    93.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 1       8/6/04   113.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 2     10/10/14   105.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 3       3/9/12   122.0  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
# 4       2/5/09   118.0           [{'iso_639_1': 'ko', 'name': '한국어/조선말'}]
#
#      status                                            tagline  \
# 0  Released  The Laws of Space and Time are About to be Vio...
# 1  Released  It can take a lifetime to find true love; she'...
# 2  Released    The road to greatness can take you to the edge.
# 3  Released                                                NaN
# 4  Released                                                NaN
#
#                                       title  \
# 0                    Hot Tub Time Machine 2
# 1  The Princess Diaries 2: Royal Engagement
# 2                                  Whiplash
# 3                                   Kahaani
# 4                                Marine Boy
#
#                                             Keywords  \
# 0  [{'id': 4379, 'name': 'time travel'}, {'id': 9...
# 1  [{'id': 2505, 'name': 'coronation'}, {'id': 42...
# 2  [{'id': 1416, 'name': 'jazz'}, {'id': 1523, 'n...
# 3  [{'id': 10092, 'name': 'mystery'}, {'id': 1054...
# 4                                                NaN
#
#                                                 cast  \
# 0  [{'cast_id': 4, 'character': 'Lou', 'credit_id...
# 1  [{'cast_id': 1, 'character': 'Mia Thermopolis'...
# 2  [{'cast_id': 5, 'character': 'Andrew Neimann',...
# 3  [{'cast_id': 1, 'character': 'Vidya Bagchi', '...
# 4  [{'cast_id': 3, 'character': 'Chun-soo', 'cred...
#
#                                                 crew   revenue
# 0  [{'credit_id': '59ac067c92514107af02c8c8', 'de...  12314651
# 1  [{'credit_id': '52fe43fe9251416c7502563d', 'de...  95149435
# 2  [{'credit_id': '54d5356ec3a3683ba0000039', 'de...  13092000
# 3  [{'credit_id': '52fe48779251416c9108d6eb', 'de...  16000000
# 4  [{'credit_id': '52fe464b9251416c75073b43', 'de...   3923970
#
# [5 rows x 23 columns]

# %% [markdown]
# 👀🎬🎭 The IMDb dataset contains information about movies, including the movie title, release year, rating, budget, runtime, popularity and many more..

# %% [markdown]
# ## **apply()**
#
# This method applies a function to every row in a pandas dataframe.
# It comes in handy when you need to perform complicated operations on a dataframe

# %% [markdown]
# 🎉🐼 The apply() function in pandas 🐼🎉 is like a 🛠️ tool kit 🧰 that helps you modify each 📊 element 📊 of a DataFrame in a unique way. You can use built-in Python functions 🐍 or create your own custom functions 👨‍💻 to get the desired output.
#
# 🔍 The apply() function can be used on a specific axis of the DataFrame 📉 (either rows or columns) or on the entire DataFrame itself . Once applied to a specific axis, the function goes on to modify each row or column  individually, and the result of the function is returned as a Series .

# %%
imdb_df['budget'].describe()
# Out:
# count    3.000000e+03
# mean     2.253133e+07
# std      3.702609e+07
# min      0.000000e+00
# 25%      0.000000e+00
# 50%      8.000000e+06
# 75%      2.900000e+07
# max      3.800000e+08
# Name: budget, dtype: float64

# %%
def func_name(column):
  if column > 8000000:
     return "High"
  else:
     return "Low"

# %%
imdb_df['budget_class'] = imdb_df['budget'].apply(func_name)
imdb_df[['budget_class','budget']]
# Out:
#      budget_class    budget
# 0            High  14000000
# 1            High  40000000
# 2             Low   3300000
# 3             Low   1200000
# 4             Low         0
# ...           ...       ...
# 2995          Low         0
# 2996          Low         0
# 2997         High  65000000
# 2998         High  42000000
# 2999         High  35000000
#
# [3000 rows x 2 columns]

# %%
imdb_df['title']
# Out:
# 0                         Hot Tub Time Machine 2
# 1       The Princess Diaries 2: Royal Engagement
# 2                                       Whiplash
# 3                                        Kahaani
# 4                                     Marine Boy
#                           ...
# 2995                                     Chasers
# 2996                            We Are the Best!
# 2997                     The Long Kiss Goodnight
# 2998                            Along Came Polly
# 2999                                   Abduction
# Name: title, Length: 3000, dtype: object

# %%
# Suppose we want to convert the column network to uppercase

def to_uppercase(column):
  return column.upper()

# %%
def to_uppercase(column):
  return column.upper()

# %%
imdb_df['capitialized_title'] = imdb_df['title'].apply(to_uppercase)
imdb_df[['capitialized_title','title']].head()
# Out:
#                          capitialized_title  \
# 0                    HOT TUB TIME MACHINE 2
# 1  THE PRINCESS DIARIES 2: ROYAL ENGAGEMENT
# 2                                  WHIPLASH
# 3                                   KAHAANI
# 4                                MARINE BOY
#
#                                       title
# 0                    Hot Tub Time Machine 2
# 1  The Princess Diaries 2: Royal Engagement
# 2                                  Whiplash
# 3                                   Kahaani
# 4                                Marine Boy

# %% [markdown]
# ### **Another way to use apply() involves the use of lambda() function.**
#
# * A lambda() function is a small anonymous function.
# * A lambda() function can take any number of arguments, but can only have one expression.

# %% [markdown]
#  Lambda functions are like tiny ninjas 🥷 that come in and perform a single task 💪 before disappearing into the shadows. They're also known as anonymous functions because they don't have a name like regular functions do.
#
# Lambda functions are useful when you need to perform a quick operation on a piece of data, like ➕ adding or ✖ multiplying, but you don't want to define a whole new function just for that one task. Think of it like calling in a ninja 🥷 to perform a quick strike and disappear without a trace!
#
# You can use lambda functions in many different situations, from filtering data to sorting and grouping. Just like a ninja, they're quick, efficient, and deadly! 😎🥷

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
def func_name(column):
  if column > 8000000:
    return "High"
  else:
    return "Low"

# %%
imdb_df['budget_class'] = imdb_df['budget'].apply(func_name)

# %%
# lambda function - Row wise operation #When 2 or more columns are involved
def revised_profit(revenue, budget):
  if revenue > 0:
    new_profit = revenue - budget
  else:
    new_profit = np.nan

  return new_profit

# %%
imdb_df[['revenue','budget']].apply(revised_profit)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-15-9a45e908f872> in <cell line: 1>()
# ----> 1 imdb_df[['revenue','budget']].apply(revised_profit)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in apply(self, func, axis, raw, result_type, args, **kwargs)
#    9566             kwargs=kwargs,
#    9567         )
# -> 9568         return op.apply().__finalize__(self, method="apply")
#    9569
#    9570     def applymap(
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/apply.py in apply(self)
#     762             return self.apply_raw()
#     763
# --> 764         return self.apply_standard()
#     765
#     766     def agg(self):
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/apply.py in apply_standard(self)
#     889
#     890     def apply_standard(self):
# --> 891         results, res_index = self.apply_series_generator()
#     892
#     893         # wrap results
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/apply.py in apply_series_generator(self)
#     905             for i, v in enumerate(series_gen):
#     906                 # ignore SettingWithCopy here in case the user mutates
# --> 907                 results[i] = self.f(v)
#     908                 if isinstance(results[i], ABCSeries):
#     909                     # If we have a view on v, we need to make a copy because
#
# TypeError: revised_profit() missing 1 required positional argument: 'budget'

# %%
imdb_df['new_profit_1'] = imdb_df.apply(lambda x: revised_profit(x['revenue'], x['budget']),axis = 1)
imdb_df[['revenue','budget',"new_profit_1"]]
# Out:
#         revenue    budget  new_profit_1
# 0      12314651  14000000      -1685349
# 1      95149435  40000000      55149435
# 2      13092000   3300000       9792000
# 3      16000000   1200000      14800000
# 4       3923970         0       3923970
# ...         ...       ...           ...
# 2995    1596687         0       1596687
# 2996     180590         0        180590
# 2997   89456761  65000000      24456761
# 2998  171963386  42000000     129963386
# 2999   82087155  35000000      47087155
#
# [3000 rows x 3 columns]

# %% [markdown]
# This code defines a function called revised_profit that takes two arguments, revenue and budget, and returns a new profit value if the revenue is greater than 0, or NaN if the revenue is less than or equal to 0.
#
# The apply() function is then used on the imdb_df DataFrame to apply the revised_profit function to each row of the DataFrame. The lambda function takes each row of the DataFrame as input and passes the values of the revenue and budget columns to the revised_profit function. The result of the function is then assigned to a new column in the DataFrame called new_profit.

# %%
imdb_df[['new_profit_1','revenue','budget']].head()
# Out:
#    new_profit_1   revenue    budget
# 0      -1685349  12314651  14000000
# 1      55149435  95149435  40000000
# 2       9792000  13092000   3300000
# 3      14800000  16000000   1200000
# 4       3923970   3923970         0

# %% [markdown]
# ##<b>Activity 1:

# %% [markdown]
# 🎥🍿 Want to analyze profits of your favorite movies?💰🤑 Use Pandas and create a new column "profit" to find out the difference between revenue and budget!📊 Then, apply a lambda function to create a "profit_margin" column that calculates the profit margin of each movie as the ratio of its profit to its revenue.😎📈 And don't forget to add a new column "is_profitable" that indicates whether each movie is profitable or not based on its profit!🤔 Finally, print the first 10 rows to see if the new columns have been added correctly.👀

# %%
round(1/3,2)
# Out:
# 0.33

# %%
def profit_margin(revenue,budget):
   if revenue > 0:
    new_profit_margin = round((revenue - budget)*100/revenue,2)
   else:
    new_profit_margin = np.nan

   return new_profit_margin

def is_profitable(revenue,budget):
  if revenue > 0:
    if revenue >budget:
      return "Profitable"
    else:
      return "Not profitable"

  else:
    return np.nan

# %%
imdb_df['Profit_margin(%)'] = imdb_df.apply(lambda x:profit_margin(x['revenue'], x['budget']) ,axis = 1 )
imdb_df['is_profitable'] = imdb_df.apply(lambda x: is_profitable(x['revenue'], x['budget']),axis =1)
imdb_df[['title','Profit_margin(%)','is_profitable','revenue','budget','new_profit_1']].sort_values('new_profit_1',ascending = False).head(10)
# Out:
#                                       title  Profit_margin(%) is_profitable  \
# 1761                              Furious 7             87.39    Profitable
# 1126                           The Avengers             85.52    Profitable
# 2770                Avengers: Age of Ultron             80.08    Profitable
# 684                    Beauty and the Beast             87.33    Profitable
# 2322         Transformers: Dark of the Moon             82.65    Profitable
# 734                                Zootopia             85.35    Profitable
# 1735                          Jurassic Park             93.15    Profitable
# 543   The Lord of the Rings: The Two Towers             91.47    Profitable
# 906                   The Dark Knight Rises             76.96    Profitable
# 2562                           Finding Dory             80.56    Profitable
#
#          revenue     budget  new_profit_1
# 1761  1506249360  190000000    1316249360
# 1126  1519557910  220000000    1299557910
# 2770  1405403694  280000000    1125403694
# 684   1262886337  160000000    1102886337
# 2322  1123746996  195000000     928746996
# 734   1023784195  150000000     873784195
# 1735   920100000   63000000     857100000
# 543    926287400   79000000     847287400
# 906   1084939099  250000000     834939099
# 2562  1028570889  200000000     828570889

# %% [markdown]
# ## <b>Merge  Operations in Pandas

# %% [markdown]
# 👥🔗 Merge operation is like a superpower 💪 in the world of data manipulation! It is used to combine two or more datasets based on a common variable. In other words, we can merge or combine data from different sources that share a common column or attribute. For example, imagine you have one dataset with movie titles 🎬 and another dataset with movie ratings 🌟. By using the merge operation, you can combine the two datasets based on the movie title, allowing you to analyze the data in a more comprehensive manner. 📈💻

# %% [markdown]
# We can merge dataframes using the following methods
#
# * <code> pd.concat( [df] , axis) </code>
#
# * <code> pd.merge( df1, df2 ,on,how,suffixes) </code>

# %% [markdown]
# ### Let us understand more of this operation by implementation on IMDb dataset.

# %% [markdown]
# To begin, let's say we have downloaded the IMDb dataset and imported it into our notebook.

# %%
# Importing  pandas and numpy

import pandas as pd
import numpy as np

# %%
file_path = '/content/imdb_data (1).csv'
imdb_df=pd.read_csv(file_path)

# %%
imdb_df.head()
# Out:
#    id                              belongs_to_collection    budget  \
# 0   1  [{'id': 313576, 'name': 'Hot Tub Time Machine ...  14000000
# 1   2  [{'id': 107674, 'name': 'The Princess Diaries ...  40000000
# 2   3                                                NaN   3300000
# 3   4                                                NaN   1200000
# 4   5                                                NaN         0
#
#                                               genres  \
# 0                     [{'id': 35, 'name': 'Comedy'}]
# 1  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 2                      [{'id': 18, 'name': 'Drama'}]
# 3  [{'id': 53, 'name': 'Thriller'}, {'id': 18, 'n...
# 4  [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...
#
#                             homepage    imdb_id original_language  \
# 0                                NaN  tt2637294                en
# 1                                NaN  tt0368933                en
# 2  http://sonyclassics.com/whiplash/  tt2582802                en
# 3         http://kahaanithefilm.com/  tt1821480                hi
# 4                                NaN  tt1380152                ko
#
#                              original_title  \
# 0                    Hot Tub Time Machine 2
# 1  The Princess Diaries 2: Royal Engagement
# 2                                  Whiplash
# 3                                   Kahaani
# 4                                      마린보이
#
#                                             overview  popularity  ...  \
# 0  When Lou, who has become the "father of the In...    6.575393  ...
# 1  Mia Thermopolis is now a college graduate and ...    8.248895  ...
# 2  Under the direction of a ruthless instructor, ...   64.299990  ...
# 3  Vidya Bagchi (Vidya Balan) arrives in Kolkata ...    3.174936  ...
# 4  Marine Boy is the story of a former national s...    1.148070  ...
#
#   release_date runtime                                   spoken_languages  \
# 0      2/20/15    93.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 1       8/6/04   113.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 2     10/10/14   105.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 3       3/9/12   122.0  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
# 4       2/5/09   118.0           [{'iso_639_1': 'ko', 'name': '한국어/조선말'}]
#
#      status                                            tagline  \
# 0  Released  The Laws of Space and Time are About to be Vio...
# 1  Released  It can take a lifetime to find true love; she'...
# 2  Released    The road to greatness can take you to the edge.
# 3  Released                                                NaN
# 4  Released                                                NaN
#
#                                       title  \
# 0                    Hot Tub Time Machine 2
# 1  The Princess Diaries 2: Royal Engagement
# 2                                  Whiplash
# 3                                   Kahaani
# 4                                Marine Boy
#
#                                             Keywords  \
# 0  [{'id': 4379, 'name': 'time travel'}, {'id': 9...
# 1  [{'id': 2505, 'name': 'coronation'}, {'id': 42...
# 2  [{'id': 1416, 'name': 'jazz'}, {'id': 1523, 'n...
# 3  [{'id': 10092, 'name': 'mystery'}, {'id': 1054...
# 4                                                NaN
#
#                                                 cast  \
# 0  [{'cast_id': 4, 'character': 'Lou', 'credit_id...
# 1  [{'cast_id': 1, 'character': 'Mia Thermopolis'...
# 2  [{'cast_id': 5, 'character': 'Andrew Neimann',...
# 3  [{'cast_id': 1, 'character': 'Vidya Bagchi', '...
# 4  [{'cast_id': 3, 'character': 'Chun-soo', 'cred...
#
#                                                 crew   revenue
# 0  [{'credit_id': '59ac067c92514107af02c8c8', 'de...  12314651
# 1  [{'credit_id': '52fe43fe9251416c7502563d', 'de...  95149435
# 2  [{'credit_id': '54d5356ec3a3683ba0000039', 'de...  13092000
# 3  [{'credit_id': '52fe48779251416c9108d6eb', 'de...  16000000
# 4  [{'credit_id': '52fe464b9251416c75073b43', 'de...   3923970
#
# [5 rows x 23 columns]

# %% [markdown]
# 👀🎬🎭 The IMDb dataset contains information about movies, including the movie title, release year, rating, budget, runtime, popularity and many more..

# %% [markdown]
# ### Let us go ✋ ahead and create three subsets of our  original dataset

# %%
# Create three dataframes : Binary Indexing
imdb1 = imdb_df[imdb_df['runtime'] >= 150] #All rows that have runtime more than 150
imdb2 = imdb_df[ (imdb_df['runtime'] < 150) & (imdb_df['runtime'] > 100 )]#All rows that have runtime less than 150 and more than 100
imdb3 = imdb_df[imdb_df['runtime'] <= 100] #All rows that has a value less than 100

#Null values doesn't have any number - Not be a part of any of the 3 df, automatically when concat it will be removed

# %% [markdown]
# Here's what's happening in the code:
#
#
# * imdb_df['runtime'] selects the **runtime column** from the imdb_df dataframe.
#
# * imdb1 = imdb_df[imdb_df['runtime'] >= 150] selects all rows from imdb_df
# where the **runtime column is greater than or equal to 150**, and assigns them to the imdb1 dataframe.
#
# * imdb2 = imdb_df[(imdb_df['runtime'] < 150) & (imdb_df['runtime'] > 100)] selects all rows from imdb_df where the **runtime column is between 100 and 150 (exclusive)**, and assigns them to the imdb2 dataframe. The & symbol is used to combine two conditions (both must be true to select the row).
#
# * imdb3 = imdb_df[imdb_df['runtime'] <= 100] selects all rows from imdb_df where the** runtime column is less than or equal to 100**, and assigns them to the imdb3 dataframe.
# These three dataframes can now be used for further analysis, such as comparing the ratings or genres of movies with different runtimes.

# %%
imdb1.head()
# Out:
#       id belongs_to_collection    budget  \
# 47    48                   NaN  44000000
# 51    52                   NaN  12000000
# 76    77                   NaN    500000
# 97    98                   NaN         0
# 107  108                   NaN  72000000
#
#                                                 genres  \
# 47   [{'id': 80, 'name': 'Crime'}, {'id': 18, 'name...
# 51   [{'id': 12, 'name': 'Adventure'}, {'id': 35, '...
# 76   [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'n...
# 97   [{'id': 14, 'name': 'Fantasy'}, {'id': 18, 'na...
# 107  [{'id': 28, 'name': 'Action'}, {'id': 18, 'nam...
#
#                         homepage    imdb_id original_language  \
# 47   http://thehatefuleight.com/  tt3460252                en
# 51                           NaN  tt0059243                en
# 76                           NaN  tt0242572                ta
# 97                           NaN  tt1772980                ru
# 107                          NaN  tt0112573                en
#
#                 original_title  \
# 47           The Hateful Eight
# 51              The Great Race
# 76   Kandukondain Kandukondain
# 97                      Mishen
# 107                 Braveheart
#
#                                               overview  popularity  ...  \
# 47   Bounty hunters seek shelter from a raging bliz...   20.328822  ...
# 51   Professional daredevil and white-suited hero, ...    4.473327  ...
# 76   Two young women with differing views on love f...    0.660663  ...
# 97   In the year 2020, a group of wealthy Moscovite...    1.042112  ...
# 107  Enraged at the slaughter of Murron, his new br...   20.755149  ...
#
#     release_date runtime                                   spoken_languages  \
# 47      12/25/15   167.0  [{'iso_639_1': 'es', 'name': 'Español'}, {'iso...
# 51        7/1/65   160.0  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
# 76        5/5/00   157.0  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
# 97       6/26/11   158.0  [{'iso_639_1': 'de', 'name': 'Deutsch'}, {'iso...
# 107      5/24/95   177.0  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
#
#        status                                            tagline  \
# 47   Released   No one comes up here without a damn good reason.
# 51   Released  The movie with 20,000-mile or one-million-laug...
# 76   Released                                                NaN
# 97   Released                                                NaN
# 107  Released         Every man dies. Not every man truly lives.
#
#                          title  \
# 47           The Hateful Eight
# 51              The Great Race
# 76   Kandukondain Kandukondain
# 97                      Target
# 107                 Braveheart
#
#                                               Keywords  \
# 47   [{'id': 801, 'name': 'bounty hunter'}, {'id': ...
# 51   [{'id': 9253, 'name': 'slapstick'}, {'id': 159...
# 76                                                 NaN
# 97                                                 NaN
# 107  [{'id': 30, 'name': 'individual'}, {'id': 388,...
#
#                                                   cast  \
# 47   [{'cast_id': 22, 'character': 'Major Marquis W...
# 51   [{'cast_id': 1, 'character': 'Prof. Fate', 'cr...
# 76   [{'cast_id': 1, 'character': 'Manohar', 'credi...
# 97   [{'cast_id': 1001, 'character': 'Victor', 'cre...
# 107  [{'cast_id': 5, 'character': 'William Wallace'...
#
#                                                   crew    revenue
# 47   [{'credit_id': '538aa95ec3a368714e0005b3', 'de...  155760117
# 51   [{'credit_id': '52fe445e9251416c75032581', 'de...   25333333
# 76   [{'credit_id': '52fe47c7c3a368484e0d8f41', 'de...     500000
# 97   [{'credit_id': '58cdbad4c3a36850e9011085', 'de...      73000
# 107  [{'credit_id': '52fe4225c3a36847f80079c1', 'de...  210000000
#
# [5 rows x 23 columns]

# %%
imdb2.head()
# Out:
#     id                              belongs_to_collection    budget  \
# 1    2  [{'id': 107674, 'name': 'The Princess Diaries ...  40000000
# 2    3                                                NaN   3300000
# 3    4                                                NaN   1200000
# 4    5                                                NaN         0
# 10  11  [{'id': 1575, 'name': 'Rocky Collection', 'pos...   1000000
#
#                                                genres  \
# 1   [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 2                       [{'id': 18, 'name': 'Drama'}]
# 3   [{'id': 53, 'name': 'Thriller'}, {'id': 18, 'n...
# 4   [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...
# 10                      [{'id': 18, 'name': 'Drama'}]
#
#                              homepage    imdb_id original_language  \
# 1                                 NaN  tt0368933                en
# 2   http://sonyclassics.com/whiplash/  tt2582802                en
# 3          http://kahaanithefilm.com/  tt1821480                hi
# 4                                 NaN  tt1380152                ko
# 10                                NaN  tt0075148                en
#
#                               original_title  \
# 1   The Princess Diaries 2: Royal Engagement
# 2                                   Whiplash
# 3                                    Kahaani
# 4                                       마린보이
# 10                                     Rocky
#
#                                              overview  popularity  ...  \
# 1   Mia Thermopolis is now a college graduate and ...    8.248895  ...
# 2   Under the direction of a ruthless instructor, ...   64.299990  ...
# 3   Vidya Bagchi (Vidya Balan) arrives in Kolkata ...    3.174936  ...
# 4   Marine Boy is the story of a former national s...    1.148070  ...
# 10  When world heavyweight boxing champion, Apollo...   14.774066  ...
#
#    release_date runtime                                   spoken_languages  \
# 1        8/6/04   113.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 2      10/10/14   105.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 3        3/9/12   122.0  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
# 4        2/5/09   118.0           [{'iso_639_1': 'ko', 'name': '한국어/조선말'}]
# 10     11/21/76   119.0           [{'iso_639_1': 'en', 'name': 'English'}]
#
#       status                                            tagline  \
# 1   Released  It can take a lifetime to find true love; she'...
# 2   Released    The road to greatness can take you to the edge.
# 3   Released                                                NaN
# 4   Released                                                NaN
# 10  Released          His whole life was a million-to-one shot.
#
#                                        title  \
# 1   The Princess Diaries 2: Royal Engagement
# 2                                   Whiplash
# 3                                    Kahaani
# 4                                 Marine Boy
# 10                                     Rocky
#
#                                              Keywords  \
# 1   [{'id': 2505, 'name': 'coronation'}, {'id': 42...
# 2   [{'id': 1416, 'name': 'jazz'}, {'id': 1523, 'n...
# 3   [{'id': 10092, 'name': 'mystery'}, {'id': 1054...
# 4                                                 NaN
# 10  [{'id': 240, 'name': 'underdog'}, {'id': 276, ...
#
#                                                  cast  \
# 1   [{'cast_id': 1, 'character': 'Mia Thermopolis'...
# 2   [{'cast_id': 5, 'character': 'Andrew Neimann',...
# 3   [{'cast_id': 1, 'character': 'Vidya Bagchi', '...
# 4   [{'cast_id': 3, 'character': 'Chun-soo', 'cred...
# 10  [{'cast_id': 16, 'character': 'Rocky Balboa', ...
#
#                                                  crew    revenue
# 1   [{'credit_id': '52fe43fe9251416c7502563d', 'de...   95149435
# 2   [{'credit_id': '54d5356ec3a3683ba0000039', 'de...   13092000
# 3   [{'credit_id': '52fe48779251416c9108d6eb', 'de...   16000000
# 4   [{'credit_id': '52fe464b9251416c75073b43', 'de...    3923970
# 10  [{'credit_id': '579948e9c3a36874e9007b0b', 'de...  117235147
#
# [5 rows x 23 columns]

# %%
imdb3.head()
# Out:
#    id                              belongs_to_collection    budget  \
# 0   1  [{'id': 313576, 'name': 'Hot Tub Time Machine ...  14000000
# 5   6                                                NaN   8000000
# 6   7                                                NaN  14000000
# 7   8                                                NaN         0
# 8   9  [{'id': 256377, 'name': 'The Muppet Collection...         0
#
#                                               genres  \
# 0                     [{'id': 35, 'name': 'Comedy'}]
# 5  [{'id': 16, 'name': 'Animation'}, {'id': 12, '...
# 6  [{'id': 27, 'name': 'Horror'}, {'id': 53, 'nam...
# 7                [{'id': 99, 'name': 'Documentary'}]
# 8  [{'id': 28, 'name': 'Action'}, {'id': 35, 'nam...
#
#                              homepage    imdb_id original_language  \
# 0                                 NaN  tt2637294                en
# 5                                 NaN  tt0093743                en
# 6  http://www.thepossessionmovie.com/  tt0431021                en
# 7                                 NaN  tt0391024                en
# 8                                 NaN  tt0117110                en
#
#                            original_title  \
# 0                  Hot Tub Time Machine 2
# 5  Pinocchio and the Emperor of the Night
# 6                          The Possession
# 7                            Control Room
# 8                  Muppet Treasure Island
#
#                                             overview  popularity  ...  \
# 0  When Lou, who has become the "father of the In...    6.575393  ...
# 5  Pinocchio and his friends, a glow worm and a m...    0.743274  ...
# 6  A young girl buys an antique box at a yard sal...    7.286477  ...
# 7  A chronicle which provides a rare window into ...    1.949044  ...
# 8  After telling the story of Flint's last journe...    6.902423  ...
#
#   release_date runtime                                   spoken_languages  \
# 0      2/20/15    93.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 5       8/6/87    83.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 6      8/30/12    92.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 7      1/15/04    84.0  [{'iso_639_1': 'ar', 'name': 'العربية'}, {'iso...
# 8      2/16/96   100.0           [{'iso_639_1': 'en', 'name': 'English'}]
#
#      status                                            tagline  \
# 0  Released  The Laws of Space and Time are About to be Vio...
# 5  Released                                                NaN
# 6  Released               Fear The Demon That Doesn't Fear God
# 7  Released              Different channels. Different truths.
# 8  Released                        Set sail for Muppet mayhem!
#
#                                     title  \
# 0                  Hot Tub Time Machine 2
# 5  Pinocchio and the Emperor of the Night
# 6                          The Possession
# 7                            Control Room
# 8                  Muppet Treasure Island
#
#                                             Keywords  \
# 0  [{'id': 4379, 'name': 'time travel'}, {'id': 9...
# 5                                                NaN
# 6                                                NaN
# 7  [{'id': 917, 'name': 'journalism'}, {'id': 163...
# 8  [{'id': 2041, 'name': 'island'}, {'id': 4418, ...
#
#                                                 cast  \
# 0  [{'cast_id': 4, 'character': 'Lou', 'credit_id...
# 5  [{'cast_id': 6, 'character': 'Pinocchio (voice...
# 6  [{'cast_id': 23, 'character': 'Clyde', 'credit...
# 7  [{'cast_id': 2, 'character': 'Himself', 'credi...
# 8  [{'cast_id': 1, 'character': 'Long John Silver...
#
#                                                 crew   revenue
# 0  [{'credit_id': '59ac067c92514107af02c8c8', 'de...  12314651
# 5  [{'credit_id': '52fe46f49251416c9106558b', 'de...   3261638
# 6  [{'credit_id': '52fe4981c3a368484e12ee29', 'de...  85446075
# 7  [{'credit_id': '52fe47a69251416c750a0daf', 'de...   2586511
# 8  [{'credit_id': '52fe43c89251416c7501deb3', 'de...  34327391
#
# [5 rows x 23 columns]

# %% [markdown]
# 👍🎉 Great! Now that we have created three new dataframes based on movie runtimes, we can perform further analysis on them.

# %%
# Concat both axis
imdb_non_null_runtime = pd.concat([imdb1,imdb2,imdb3],axis =0) #default: This stacks one below the other axis = 0
imdb_non_null_runtime
# Out:
#         id belongs_to_collection    budget  \
# 47      48                   NaN  44000000
# 51      52                   NaN  12000000
# 76      77                   NaN    500000
# 97      98                   NaN         0
# 107    108                   NaN  72000000
# ...    ...                   ...       ...
# 2987  2988                   NaN         0
# 2988  2989                   NaN         0
# 2989  2990                   NaN         0
# 2990  2991                   NaN         0
# 2998  2999                   NaN  42000000
#
#                                                  genres  \
# 47    [{'id': 80, 'name': 'Crime'}, {'id': 18, 'name...
# 51    [{'id': 12, 'name': 'Adventure'}, {'id': 35, '...
# 76    [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'n...
# 97    [{'id': 14, 'name': 'Fantasy'}, {'id': 18, 'na...
# 107   [{'id': 28, 'name': 'Action'}, {'id': 18, 'nam...
# ...                                                 ...
# 2987  [{'id': 27, 'name': 'Horror'}, {'id': 878, 'na...
# 2988                      [{'id': 18, 'name': 'Drama'}]
# 2989  [{'id': 16, 'name': 'Animation'}, {'id': 10751...
# 2990  [{'id': 28, 'name': 'Action'}, {'id': 35, 'nam...
# 2998  [{'id': 35, 'name': 'Comedy'}, {'id': 10749, '...
#
#                             homepage    imdb_id original_language  \
# 47       http://thehatefuleight.com/  tt3460252                en
# 51                               NaN  tt0059243                en
# 76                               NaN  tt0242572                ta
# 97                               NaN  tt1772980                ru
# 107                              NaN  tt0112573                en
# ...                              ...        ...               ...
# 2987                             NaN  tt0096246                en
# 2988                             NaN  tt0301978                fa
# 2989                             NaN  tt0206367                en
# 2990                             NaN  tt0118663                en
# 2998  http://www.alongcamepolly.com/  tt0343135                en
#
#                  original_title  \
# 47            The Hateful Eight
# 51               The Great Race
# 76    Kandukondain Kandukondain
# 97                       Mishen
# 107                  Braveheart
# ...                         ...
# 2987          The Terror Within
# 2988                         ده
# 2989    The Trumpet Of The Swan
# 2990                   B.A.P.S.
# 2998           Along Came Polly
#
#                                                overview  popularity  ...  \
# 47    Bounty hunters seek shelter from a raging bliz...   20.328822  ...
# 51    Professional daredevil and white-suited hero, ...    4.473327  ...
# 76    Two young women with differing views on love f...    0.660663  ...
# 97    In the year 2020, a group of wealthy Moscovite...    1.042112  ...
# 107   Enraged at the slaughter of Murron, his new br...   20.755149  ...
# ...                                                 ...         ...  ...
# 2987  Experiments in biological warfare have destroy...    1.292125  ...
# 2988  A visual social examination in the form of ten...    0.984515  ...
# 2989  The adventures of a young Trumpeter swan who c...    0.851599  ...
# 2990  Can two clueless Georgia homegirls with big he...    1.560980  ...
# 2998  Reuben Feffer is a guy who's spent his entire ...   15.725542  ...
#
#      release_date runtime                                   spoken_languages  \
# 47       12/25/15   167.0  [{'iso_639_1': 'es', 'name': 'Español'}, {'iso...
# 51         7/1/65   160.0  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
# 76         5/5/00   157.0  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
# 97        6/26/11   158.0  [{'iso_639_1': 'de', 'name': 'Deutsch'}, {'iso...
# 107       5/24/95   177.0  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
# ...           ...     ...                                                ...
# 2987      1/20/89    90.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 2988      5/20/02    94.0             [{'iso_639_1': 'fa', 'name': 'فارسی'}]
# 2989      5/11/01    75.0  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
# 2990      3/28/97    90.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 2998      1/16/04    90.0           [{'iso_639_1': 'en', 'name': 'English'}]
#
#         status                                            tagline  \
# 47    Released   No one comes up here without a damn good reason.
# 51    Released  The movie with 20,000-mile or one-million-laug...
# 76    Released                                                NaN
# 97    Released                                                NaN
# 107   Released         Every man dies. Not every man truly lives.
# ...        ...                                                ...
# 2987  Released                               It Wants To Get Out!
# 2988  Released                                                NaN
# 2989  Released  Sometimes being different helps you to find yo...
# 2990  Released                These Pretty Women... Are Clueless!
# 2998  Released  For the most cautious man on Earth, life is ab...
#
#                           title  \
# 47            The Hateful Eight
# 51               The Great Race
# 76    Kandukondain Kandukondain
# 97                       Target
# 107                  Braveheart
# ...                         ...
# 2987          The Terror Within
# 2988                        Ten
# 2989    The Trumpet Of The Swan
# 2990                   B.A.P.S.
# 2998           Along Came Polly
#
#                                                Keywords  \
# 47    [{'id': 801, 'name': 'bounty hunter'}, {'id': ...
# 51    [{'id': 9253, 'name': 'slapstick'}, {'id': 159...
# 76                                                  NaN
# 97                                                  NaN
# 107   [{'id': 30, 'name': 'individual'}, {'id': 388,...
# ...                                                 ...
# 2987  [{'id': 1299, 'name': 'monster'}, {'id': 1852,...
# 2988  [{'id': 1156, 'name': 'sister sister relations...
# 2989  [{'id': 6653, 'name': 'trumpet'}, {'id': 10407...
# 2990  [{'id': 1437, 'name': 'burglar'}, {'id': 1946,...
# 2998  [{'id': 966, 'name': 'beach'}, {'id': 2676, 'n...
#
#                                                    cast  \
# 47    [{'cast_id': 22, 'character': 'Major Marquis W...
# 51    [{'cast_id': 1, 'character': 'Prof. Fate', 'cr...
# 76    [{'cast_id': 1, 'character': 'Manohar', 'credi...
# 97    [{'cast_id': 1001, 'character': 'Victor', 'cre...
# 107   [{'cast_id': 5, 'character': 'William Wallace'...
# ...                                                 ...
# 2987  [{'cast_id': 4, 'character': 'Hal', 'credit_id...
# 2988  [{'cast_id': 2, 'character': 'Driver', 'credit...
# 2989  [{'cast_id': 1, 'character': 'Father', 'credit...
# 2990  [{'cast_id': 3, 'character': 'Nisi', 'credit_i...
# 2998  [{'cast_id': 8, 'character': 'Reuben Feffer', ...
#
#                                                    crew    revenue
# 47    [{'credit_id': '538aa95ec3a368714e0005b3', 'de...  155760117
# 51    [{'credit_id': '52fe445e9251416c75032581', 'de...   25333333
# 76    [{'credit_id': '52fe47c7c3a368484e0d8f41', 'de...     500000
# 97    [{'credit_id': '58cdbad4c3a36850e9011085', 'de...      73000
# 107   [{'credit_id': '52fe4225c3a36847f80079c1', 'de...  210000000
# ...                                                 ...        ...
# 2987  [{'credit_id': '52fe45d9c3a368484e072511', 'de...     858591
# 2988  [{'credit_id': '52fe460a9251416c7506b0a7', 'de...     105656
# 2989  [{'credit_id': '58bc9d609251416084044b0e', 'de...     100202
# 2990  [{'credit_id': '52fe477b9251416c7509af57', 'de...    7240837
# 2998  [{'credit_id': '556f817b9251410866000a63', 'de...  171963386
#
# [2998 rows x 23 columns]

# %%
imdb_non_null_runtime.shape
# Out:
# (2998, 23)

# %% [markdown]
# The axis parameter is used to specify whether an operation is applied along rows or columns.
#
# When axis=0, the operation is applied along the rows or the index axis, resulting in a reduction of the number of rows.
#
# When axis=1, the operation is applied along the columns or the column axis, resulting in a reduction of the number of columns.

# %%
# Concatenate along a particular axis
sample_df = pd.concat([imdb1, imdb2],axis=1)

# %%
sample_df.head()
# Out:
#         id belongs_to_collection      budget  \
# 47    48.0                   NaN  44000000.0
# 51    52.0                   NaN  12000000.0
# 76    77.0                   NaN    500000.0
# 97    98.0                   NaN         0.0
# 107  108.0                   NaN  72000000.0
#
#                                                 genres  \
# 47   [{'id': 80, 'name': 'Crime'}, {'id': 18, 'name...
# 51   [{'id': 12, 'name': 'Adventure'}, {'id': 35, '...
# 76   [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'n...
# 97   [{'id': 14, 'name': 'Fantasy'}, {'id': 18, 'na...
# 107  [{'id': 28, 'name': 'Action'}, {'id': 18, 'nam...
#
#                         homepage    imdb_id original_language  \
# 47   http://thehatefuleight.com/  tt3460252                en
# 51                           NaN  tt0059243                en
# 76                           NaN  tt0242572                ta
# 97                           NaN  tt1772980                ru
# 107                          NaN  tt0112573                en
#
#                 original_title  \
# 47           The Hateful Eight
# 51              The Great Race
# 76   Kandukondain Kandukondain
# 97                      Mishen
# 107                 Braveheart
#
#                                               overview  popularity  ...  \
# 47   Bounty hunters seek shelter from a raging bliz...   20.328822  ...
# 51   Professional daredevil and white-suited hero, ...    4.473327  ...
# 76   Two young women with differing views on love f...    0.660663  ...
# 97   In the year 2020, a group of wealthy Moscovite...    1.042112  ...
# 107  Enraged at the slaughter of Murron, his new br...   20.755149  ...
#
#     release_date runtime spoken_languages status  tagline title Keywords cast  \
# 47           NaN     NaN              NaN    NaN      NaN   NaN      NaN  NaN
# 51           NaN     NaN              NaN    NaN      NaN   NaN      NaN  NaN
# 76           NaN     NaN              NaN    NaN      NaN   NaN      NaN  NaN
# 97           NaN     NaN              NaN    NaN      NaN   NaN      NaN  NaN
# 107          NaN     NaN              NaN    NaN      NaN   NaN      NaN  NaN
#
#     crew revenue
# 47   NaN     NaN
# 51   NaN     NaN
# 76   NaN     NaN
# 97   NaN     NaN
# 107  NaN     NaN
#
# [5 rows x 46 columns]

# %%
sample_df.shape
# Out:
# (1721, 46)

# %%
imdb_r_1 = imdb_df[['runtime','original_title']]
imdb_r_2 = imdb_df[['runtime','revenue']]

# %%
imdb_r_2.shape
# Out:
# (3000, 2)

# %%
imdb_filter_cols = pd.concat([imdb_r_1, imdb_r_2],axis=1)

# %%
#Axis = 0 means ROWS -> commonality between columns
imdb_filter_rows = pd.concat([imdb_r_1, imdb_r_2],axis=0)

# %%
imdb_filter_cols
# Out:
#       runtime                            original_title  runtime    revenue
# 0        93.0                    Hot Tub Time Machine 2     93.0   12314651
# 1       113.0  The Princess Diaries 2: Royal Engagement    113.0   95149435
# 2       105.0                                  Whiplash    105.0   13092000
# 3       122.0                                   Kahaani    122.0   16000000
# 4       118.0                                      마린보이    118.0    3923970
# ...       ...                                       ...      ...        ...
# 2995    102.0                                   Chasers    102.0    1596687
# 2996    102.0                               Vi är bäst!    102.0     180590
# 2997    120.0                   The Long Kiss Goodnight    120.0   89456761
# 2998     90.0                          Along Came Polly     90.0  171963386
# 2999    106.0                                 Abduction    106.0   82087155
#
# [3000 rows x 4 columns]

# %%
imdb_filter_rows
# Out:
#       runtime                            original_title      revenue
# 0        93.0                    Hot Tub Time Machine 2          NaN
# 1       113.0  The Princess Diaries 2: Royal Engagement          NaN
# 2       105.0                                  Whiplash          NaN
# 3       122.0                                   Kahaani          NaN
# 4       118.0                                      마린보이          NaN
# ...       ...                                       ...          ...
# 2995    102.0                                       NaN    1596687.0
# 2996    102.0                                       NaN     180590.0
# 2997    120.0                                       NaN   89456761.0
# 2998     90.0                                       NaN  171963386.0
# 2999    106.0                                       NaN   82087155.0
#
# [6000 rows x 3 columns]

# %%
imdb_r_1 = imdb_df[['runtime','original_title']]
imdb_r_2 = imdb_df[['original_title','revenue']]
imdb_filter_cols = pd.concat([imdb_r_1, imdb_r_2],axis=0)
imdb_filter_cols
# Out:
#       runtime                            original_title      revenue
# 0        93.0                    Hot Tub Time Machine 2          NaN
# 1       113.0  The Princess Diaries 2: Royal Engagement          NaN
# 2       105.0                                  Whiplash          NaN
# 3       122.0                                   Kahaani          NaN
# 4       118.0                                      마린보이          NaN
# ...       ...                                       ...          ...
# 2995      NaN                                   Chasers    1596687.0
# 2996      NaN                               Vi är bäst!     180590.0
# 2997      NaN                   The Long Kiss Goodnight   89456761.0
# 2998      NaN                          Along Came Polly  171963386.0
# 2999      NaN                                 Abduction   82087155.0
#
# [6000 rows x 3 columns]

# %%
imdb_r_1
# Out:
#       runtime                            original_title
# 0        93.0                    Hot Tub Time Machine 2
# 1       113.0  The Princess Diaries 2: Royal Engagement
# 2       105.0                                  Whiplash
# 3       122.0                                   Kahaani
# 4       118.0                                      마린보이
# ...       ...                                       ...
# 2995    102.0                                   Chasers
# 2996    102.0                               Vi är bäst!
# 2997    120.0                   The Long Kiss Goodnight
# 2998     90.0                          Along Came Polly
# 2999    106.0                                 Abduction
#
# [3000 rows x 2 columns]

# %% [markdown]
# ##<b> Activity 2 :

# %% [markdown]
# 🍿🕰️🎬 Are you ready for a movie marathon? 🤩🎥 Let's filter the IMDb dataset for movies that are at least 2 hours long ⏰ and those with a popularity of 50.0 or higher 🌟. Then, let's concatenate these two filtered DataFrames into a new DataFrame 🤝, and sort it by popularity to find the top-rated movies with a runtime of 2 hours or more 🏆🎞️. Can you print the titles and popularity of the top 10 movies in this new DataFrame? 🤔💻🔍

# %%
imdb_df[imdb_df['runtime']>=120] # all the movies list which has >=120
# Out:
#         id                              belongs_to_collection     budget  \
# 3        4                                                NaN    1200000
# 12      13                                                NaN   15000000
# 14      15                                                NaN  102000000
# 20      21                                                NaN   80000000
# 33      34  [{'id': 207632, 'name': 'The ABCs of Death Col...          0
# ...    ...                                                ...        ...
# 2970  2971                                                NaN   25000000
# 2980  2981                                                NaN     300000
# 2992  2993                                                NaN    1135654
# 2993  2994                                                NaN   60000000
# 2997  2998                                                NaN   65000000
#
#                                                  genres  \
# 3     [{'id': 53, 'name': 'Thriller'}, {'id': 18, 'n...
# 12                        [{'id': 18, 'name': 'Drama'}]
# 14    [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...
# 20    [{'id': 12, 'name': 'Adventure'}, {'id': 10751...
# 33                       [{'id': 27, 'name': 'Horror'}]
# ...                                                 ...
# 2970  [{'id': 53, 'name': 'Thriller'}, {'id': 28, 'n...
# 2980  [{'id': 28, 'name': 'Action'}, {'id': 35, 'nam...
# 2992  [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
# 2993  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 2997  [{'id': 80, 'name': 'Crime'}, {'id': 28, 'name...
#
#                                       homepage    imdb_id original_language  \
# 3                   http://kahaanithefilm.com/  tt1821480                hi
# 12               http://www.dreamworks.com/ab/  tt0169547                en
# 14                                         NaN  tt0181689                en
# 20                                         NaN  tt0120738                en
# 33                                         NaN  tt2926810                en
# ...                                        ...        ...               ...
# 2970                                       NaN  tt0103855                en
# 2980  https://www.facebook.com/Actionherobiju/  tt5320514                ml
# 2992                                       NaN  tt0015400                en
# 2993      http://www.theterminal-themovie.com/  tt0362227                en
# 2997                                       NaN  tt0116908                en
#
#                original_title  \
# 3                     Kahaani
# 12            American Beauty
# 14            Minority Report
# 20              Lost in Space
# 33            ABCs of Death 2
# ...                       ...
# 2970            The Bodyguard
# 2980          ആക്ഷൻ ഹീറോ ബിജു
# 2992      The Thief of Bagdad
# 2993             The Terminal
# 2997  The Long Kiss Goodnight
#
#                                                overview  popularity  ...  \
# 3     Vidya Bagchi (Vidya Balan) arrives in Kolkata ...    3.174936  ...
# 12    Lester Burnham, a depressed suburban father in...   20.726578  ...
# 14    John Anderton is a top 'Precrime' cop in the l...   20.666063  ...
# 20    The prospects for continuing life on Earth in ...   12.000579  ...
# 33    Taking all that was great from the first insta...    8.254856  ...
# ...                                                 ...         ...  ...
# 2970  A former Secret Service agent grudgingly takes...    9.805017  ...
# 2980  Biju is an honest policeman who fights the inj...    0.350207  ...
# 2992  A recalcitrant thief vies with a duplicitous M...    3.878515  ...
# 2993  Viktor Navorski is a man without a country; hi...   14.092373  ...
# 2997  Samantha Caine, suburban homemaker, is the ide...   14.482345  ...
#
#                                                Keywords  \
# 3     [{'id': 10092, 'name': 'mystery'}, {'id': 1054...
# 12    [{'id': 255, 'name': 'male nudity'}, {'id': 29...
# 14    [{'id': 476, 'name': 'self-fulfilling prophecy...
# 20    [{'id': 4379, 'name': 'time travel'}, {'id': 1...
# 33    [{'id': 9706, 'name': 'anthology'}, {'id': 187...
# ...                                                 ...
# 2970  [{'id': 1156, 'name': 'sister sister relations...
# 2980  [{'id': 1252, 'name': 'suicide attempt'}, {'id...
# 2992  [{'id': 255, 'name': 'male nudity'}, {'id': 14...
# 2993  [{'id': 242, 'name': 'new york'}, {'id': 822, ...
# 2997  [{'id': 441, 'name': 'assassination'}, {'id': ...
#
#                                                    cast  \
# 3     [{'cast_id': 1, 'character': 'Vidya Bagchi', '...
# 12    [{'cast_id': 6, 'character': 'Lester Burnham',...
# 14    [{'cast_id': 5, 'character': 'Chief John Ander...
# 20    [{'cast_id': 26, 'character': 'Dr. Zachary Smi...
# 33    [{'cast_id': 60, 'character': 'Assassin (Segme...
# ...                                                 ...
# 2970  [{'cast_id': 17, 'character': 'Rachel Marron',...
# 2980  [{'cast_id': 1, 'character': 'Sub-Inspector Bi...
# 2992  [{'cast_id': 3, 'character': 'The Thief of Bag...
# 2993  [{'cast_id': 4, 'character': 'Viktor Navorski'...
# 2997  [{'cast_id': 10, 'character': 'Samantha Caine ...
#
#                                                    crew    revenue  \
# 3     [{'credit_id': '52fe48779251416c9108d6eb', 'de...   16000000
# 12    [{'credit_id': '52fe420ec3a36847f80007c5', 'de...  356296601
# 14    [{'credit_id': '52fe4223c3a36847f8006f3d', 'de...  358372926
# 20    [{'credit_id': '52fe433bc3a36847f80448b9', 'de...  136159423
# 33    [{'credit_id': '52fe4cd69251416c91101d73', 'de...       7171
# ...                                                 ...        ...
# 2970  [{'credit_id': '52fe425ec3a36847f8019133', 'de...  411006740
# 2980  [{'credit_id': '56b4d47f92514112b90045f6', 'de...    2500000
# 2992  [{'credit_id': '52fe45bec3a368484e06c70b', 'de...    1213880
# 2993  [{'credit_id': '52fe4259c3a36847f8017699', 'de...  219417255
# 2997  [{'credit_id': '52fe443a9251416c7502d579', 'de...   89456761
#
#             Capitalized_title budget_class new_profit new_profit_1  \
# 3                     KAHAANI          Low   14800000     14800000
# 12            AMERICAN BEAUTY         High  341296601    341296601
# 14            MINORITY REPORT         High  256372926    256372926
# 20              LOST IN SPACE         High   56159423     56159423
# 33            ABCS OF DEATH 2          Low       7171         7171
# ...                       ...          ...        ...          ...
# 2970            THE BODYGUARD         High  386006740    386006740
# 2980         ACTION HERO BIJU          Low    2200000      2200000
# 2992      THE THIEF OF BAGDAD          Low      78226        78226
# 2993             THE TERMINAL         High  159417255    159417255
# 2997  THE LONG KISS GOODNIGHT         High   24456761     24456761
#
#      profit_margin is_profitable
# 3            92.50    Profitable
# 12           95.79    Profitable
# 14           71.54    Profitable
# 20           41.25    Profitable
# 33          100.00    Profitable
# ...            ...           ...
# 2970         93.92    Profitable
# 2980         88.00    Profitable
# 2992          6.44    Profitable
# 2993         72.65    Profitable
# 2997         27.34    Profitable
#
# [705 rows x 29 columns]

# %%
imdb_df[imdb_df['popularity']>=50]
# Out:
#         id                              belongs_to_collection     budget  \
# 2        3                                                NaN    3300000
# 518    519  [{'id': 468552, 'name': 'Wonder Woman Collecti...  149000000
# 684    685                                                NaN  160000000
# 1126  1127  [{'id': 86311, 'name': 'The Avengers Collectio...  220000000
# 1309  1310                                                NaN   61000000
# 1673  1674  [{'id': 263, 'name': 'The Dark Knight Collecti...  185000000
# 1695  1696                                                NaN   34000000
# 1715  1716  [{'id': 173710, 'name': 'Planet of the Apes (R...  152000000
# 1783  1784  [{'id': 453993, 'name': 'The Wolverine Collect...   97000000
# 2016  2017                                                NaN   25000000
# 2018  2019  [{'id': 284433, 'name': 'Guardians of the Gala...  170000000
# 2126  2127  [{'id': 284433, 'name': 'Guardians of the Gala...  200000000
# 2293  2294                                                NaN   18000000
# 2326  2327  [{'id': 448150, 'name': 'Deadpool Collection',...   58000000
# 2338  2339                                                NaN   63000000
#
#                                                  genres  \
# 2                         [{'id': 18, 'name': 'Drama'}]
# 518   [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
# 684   [{'id': 10751, 'name': 'Family'}, {'id': 14, '...
# 1126  [{'id': 878, 'name': 'Science Fiction'}, {'id'...
# 1309  [{'id': 9648, 'name': 'Mystery'}, {'id': 53, '...
# 1673  [{'id': 18, 'name': 'Drama'}, {'id': 28, 'name...
# 1695  [{'id': 28, 'name': 'Action'}, {'id': 80, 'nam...
# 1715  [{'id': 18, 'name': 'Drama'}, {'id': 878, 'nam...
# 1783  [{'id': 28, 'name': 'Action'}, {'id': 18, 'nam...
# 2016  [{'id': 18, 'name': 'Drama'}, {'id': 80, 'name...
# 2018  [{'id': 28, 'name': 'Action'}, {'id': 878, 'na...
# 2126  [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
# 2293  [{'id': 18, 'name': 'Drama'}, {'id': 53, 'name...
# 2326  [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
# 2338                      [{'id': 18, 'name': 'Drama'}]
#
#                                                homepage    imdb_id  \
# 2                     http://sonyclassics.com/whiplash/  tt2582802
# 518              http://www.warnerbros.com/wonder-woman  tt0451279
# 684   http://movies.disney.com/beauty-and-the-beast-...  tt2771200
# 1126                  http://marvel.com/avengers_movie/  tt0848228
# 1309                      http://www.gonegirlmovie.com/  tt2267998
# 1673       http://thedarkknight.warnerbros.com/dvdsite/  tt0468569
# 1695                                                NaN  tt3890160
# 1715  http://www.foxmovies.com/movies/war-for-the-pl...  tt3450958
# 1783              http://www.foxmovies.com/movies/logan  tt3315342
# 2016                                                NaN  tt0111161
# 2018                        http://marvel.com/guardians  tt2015381
# 2126  http://marvel.com/movies/movie/221/guardians_o...  tt3896198
# 2293                         http://wearethecircle.com/  tt4287320
# 2326           http://www.foxmovies.com/movies/deadpool  tt1431045
# 2338         http://www.foxmovies.com/movies/fight-club  tt0137523
#
#      original_language                  original_title  \
# 2                   en                        Whiplash
# 518                 en                    Wonder Woman
# 684                 en            Beauty and the Beast
# 1126                en                    The Avengers
# 1309                en                       Gone Girl
# 1673                en                 The Dark Knight
# 1695                en                     Baby Driver
# 1715                en  War for the Planet of the Apes
# 1783                en                           Logan
# 2016                en        The Shawshank Redemption
# 2018                en         Guardians of the Galaxy
# 2126                en  Guardians of the Galaxy Vol. 2
# 2293                en                      The Circle
# 2326                en                        Deadpool
# 2338                en                      Fight Club
#
#                                                overview  popularity  ...  \
# 2     Under the direction of a ruthless instructor, ...   64.299990  ...
# 518   An Amazon princess comes to the world of Man t...  294.337037  ...
# 684   A live-action adaptation of Disney's version o...  287.253654  ...
# 1126  When an unexpected enemy emerges and threatens...   89.887648  ...
# 1309  With his wife's disappearance having become th...  154.801009  ...
# 1673  Batman raises the stakes in his war on crime. ...  123.167259  ...
# 1695  After being coerced into working for a crime b...  228.032744  ...
# 1715  Caesar and his apes are forced into a deadly c...  146.161786  ...
# 1783  In the near future, a weary Logan cares for an...   54.581997  ...
# 2016  Framed in the 1940s for the double murder of h...   51.645403  ...
# 2018  Light years from Earth, 26 years after being a...   53.291601  ...
# 2126  The Guardians must fight to keep their newfoun...  185.330992  ...
# 2293  A young tech worker takes a job at a greedy In...   88.439243  ...
# 2326  Deadpool tells the origin story of former Spec...  187.860492  ...
# 2338  A ticking-time-bomb insomniac and a slippery s...   63.869599  ...
#
#                                                Keywords  \
# 2     [{'id': 1416, 'name': 'jazz'}, {'id': 1523, 'n...
# 518   [{'id': 849, 'name': 'dc comics'}, {'id': 1701...
# 684   [{'id': 254, 'name': 'france'}, {'id': 2343, '...
# 1126  [{'id': 242, 'name': 'new york'}, {'id': 5539,...
# 1309  [{'id': 818, 'name': 'based on novel'}, {'id':...
# 1673  [{'id': 849, 'name': 'dc comics'}, {'id': 853,...
# 1695  [{'id': 642, 'name': 'robbery'}, {'id': 2076, ...
# 1715  [{'id': 818, 'name': 'based on novel'}, {'id':...
# 1783  [{'id': 679, 'name': 'cyborg'}, {'id': 1706, '...
# 2016  [{'id': 378, 'name': 'prison'}, {'id': 417, 'n...
# 2018  [{'id': 8828, 'name': 'marvel comic'}, {'id': ...
# 2126  [{'id': 9663, 'name': 'sequel'}, {'id': 9715, ...
# 2293  [{'id': 1576, 'name': 'technology'}, {'id': 58...
# 2326  [{'id': 2095, 'name': 'anti hero'}, {'id': 307...
# 2338  [{'id': 825, 'name': 'support group'}, {'id': ...
#
#                                                    cast  \
# 2     [{'cast_id': 5, 'character': 'Andrew Neimann',...
# 518                                                 NaN
# 684   [{'cast_id': 174, 'character': 'Belle', 'credi...
# 1126  [{'cast_id': 46, 'character': 'Tony Stark / Ir...
# 1309  [{'cast_id': 7, 'character': 'Nick Dunne', 'cr...
# 1673  [{'cast_id': 35, 'character': 'Bruce Wayne / B...
# 1695  [{'cast_id': 9, 'character': 'Baby', 'credit_i...
# 1715  [{'cast_id': 6, 'character': 'Caesar', 'credit...
# 1783                                                NaN
# 2016  [{'cast_id': 3, 'character': 'Andy Dufresne', ...
# 2018  [{'cast_id': 1, 'character': 'Peter Quill / St...
# 2126  [{'cast_id': 3, 'character': 'Peter Quill / St...
# 2293  [{'cast_id': 14, 'character': 'Mae Holland', '...
# 2326  [{'cast_id': 99, 'character': 'Wade Wilson / D...
# 2338  [{'cast_id': 4, 'character': 'The Narrator', '...
#
#                                                    crew     revenue  \
# 2     [{'credit_id': '54d5356ec3a3683ba0000039', 'de...    13092000
# 518                                                 NaN   820580447
# 684   [{'credit_id': '551879bec3a3681f840004eb', 'de...  1262886337
# 1126  [{'credit_id': '52fe4495c3a368484e02b1cf', 'de...  1519557910
# 1309  [{'credit_id': '52fe4d7fc3a368484e1ec741', 'de...   369330363
# 1673  [{'credit_id': '55a0eb4a925141296b0010f8', 'de...  1004558444
# 1695  [{'credit_id': '55c58c009251417a21000e5d', 'de...   224511319
# 1715  [{'credit_id': '591f036fc3a368774e036079', 'de...   369907963
# 1783                                                NaN   616801808
# 2016  [{'credit_id': '52fe4231c3a36847f800b127', 'de...    28341469
# 2018  [{'credit_id': '538ce329c3a3687155003358', 'de...   773328629
# 2126  [{'credit_id': '59171547925141583c0315a6', 'de...   863416141
# 2293  [{'credit_id': '55528cd792514114c8000722', 'de...    20497844
# 2326  [{'credit_id': '57e564fac3a3681beb0000cc', 'de...   783112979
# 2338  [{'credit_id': '55731b8192514111610027d7', 'de...   100853753
#
#                    Capitalized_title budget_class  new_profit new_profit_1  \
# 2                           WHIPLASH          Low     9792000      9792000
# 518                     WONDER WOMAN         High   671580447    671580447
# 684             BEAUTY AND THE BEAST         High  1102886337   1102886337
# 1126                    THE AVENGERS         High  1299557910   1299557910
# 1309                       GONE GIRL         High   308330363    308330363
# 1673                 THE DARK KNIGHT         High   819558444    819558444
# 1695                     BABY DRIVER         High   190511319    190511319
# 1715  WAR FOR THE PLANET OF THE APES         High   217907963    217907963
# 1783                           LOGAN         High   519801808    519801808
# 2016        THE SHAWSHANK REDEMPTION         High     3341469      3341469
# 2018         GUARDIANS OF THE GALAXY         High   603328629    603328629
# 2126  GUARDIANS OF THE GALAXY VOL. 2         High   663416141    663416141
# 2293                      THE CIRCLE         High     2497844      2497844
# 2326                        DEADPOOL         High   725112979    725112979
# 2338                      FIGHT CLUB         High    37853753     37853753
#
#      profit_margin is_profitable
# 2            74.79    Profitable
# 518          81.84    Profitable
# 684          87.33    Profitable
# 1126         85.52    Profitable
# 1309         83.48    Profitable
# 1673         81.58    Profitable
# 1695         84.86    Profitable
# 1715         58.91    Profitable
# 1783         84.27    Profitable
# 2016         11.79    Profitable
# 2018         78.02    Profitable
# 2126         76.84    Profitable
# 2293         12.19    Profitable
# 2326         92.59    Profitable
# 2338         37.53    Profitable
#
# [15 rows x 29 columns]

# %%
# Try out here

# Filter the dataset for movies with a runtime of 120 minutes or more
imdb_filter1 = imdb_df[imdb_df['runtime']>=120]

# Filter the dataset for movies with a popularity of 50.0 or higher
imdb_filter2 = imdb_df[imdb_df['popularity']>=50]

imdb_filter_final = pd.concat([imdb_filter1, imdb_filter2],axis=0)

final = imdb_filter_final.sort_values('popularity', ascending=False)
final[['title','runtime','popularity']]
# Out:
#                           title  runtime  popularity
# 518                Wonder Woman    141.0  294.337037
# 518                Wonder Woman    141.0  294.337037
# 684        Beauty and the Beast    129.0  287.253654
# 684        Beauty and the Beast    129.0  287.253654
# 1695                Baby Driver    113.0  228.032744
# ...                         ...      ...         ...
# 2662              Kadhal Kottai    157.0    0.071908
# 2237                    Sankofa    124.0    0.045860
# 1757      Journey from the Fall    135.0    0.044561
# 1333  One Bright Shining Moment    123.0    0.037986
# 1800         The Cherry Orchard    141.0    0.001880
#
# [720 rows x 3 columns]

# %% [markdown]
# ## **Now let's do some joins**

# %% [markdown]
# 🔗 In the context of Pandas, joins refer to operations that combine two or more dataframes based on common columns or indices. The merge() function in Pandas can be used to perform these joins.
#
# 🔢 Pandas supports four types of joins:
#
# 🔍 Inner join: Returns only the matching rows from both dataframes based on a common column or index.
#
# 🌀 Outer join: Returns all the rows from both dataframes and fills the missing values with NaN if a row is unmatched.
#
# 👈 Left join: Returns all the rows from the left dataframe and matching rows from the right dataframe. Missing values are filled with NaN if a row is unmatched.
#
# 👉 Right join: Returns all the rows from the right dataframe and matching rows from the left dataframe. Missing values are filled with NaN if a row is unmatched.

# %% [markdown]
# ![joini.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# 🤔 The type of join to use depends on the analysis being performed and the specific requirements of the task at hand.
#
#  👌So, let's dive 🤿 into each of them...

# %%
# Let us create a dataframe which consists of only English movies
english_movies = imdb_df[imdb_df['original_language'] == 'en']

# Next let us create another dataframe which consists of only those movies whose length is greater than 100 mins
long_movies = imdb_df.loc[imdb_df['runtime'] >= 100,['imdb_id','original_language']]

# %%
english_movies['original_language'].value_counts()
# Out:
# en    2575
# Name: original_language, dtype: int64

# %%
english_movies.head()
# Out:
#    id                              belongs_to_collection    budget  \
# 0   1  [{'id': 313576, 'name': 'Hot Tub Time Machine ...  14000000
# 1   2  [{'id': 107674, 'name': 'The Princess Diaries ...  40000000
# 2   3                                                NaN   3300000
# 5   6                                                NaN   8000000
# 6   7                                                NaN  14000000
#
#                                               genres  \
# 0                     [{'id': 35, 'name': 'Comedy'}]
# 1  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 2                      [{'id': 18, 'name': 'Drama'}]
# 5  [{'id': 16, 'name': 'Animation'}, {'id': 12, '...
# 6  [{'id': 27, 'name': 'Horror'}, {'id': 53, 'nam...
#
#                              homepage    imdb_id original_language  \
# 0                                 NaN  tt2637294                en
# 1                                 NaN  tt0368933                en
# 2   http://sonyclassics.com/whiplash/  tt2582802                en
# 5                                 NaN  tt0093743                en
# 6  http://www.thepossessionmovie.com/  tt0431021                en
#
#                              original_title  \
# 0                    Hot Tub Time Machine 2
# 1  The Princess Diaries 2: Royal Engagement
# 2                                  Whiplash
# 5    Pinocchio and the Emperor of the Night
# 6                            The Possession
#
#                                             overview  popularity  ...  \
# 0  When Lou, who has become the "father of the In...    6.575393  ...
# 1  Mia Thermopolis is now a college graduate and ...    8.248895  ...
# 2  Under the direction of a ruthless instructor, ...   64.299990  ...
# 5  Pinocchio and his friends, a glow worm and a m...    0.743274  ...
# 6  A young girl buys an antique box at a yard sal...    7.286477  ...
#
#   release_date runtime                          spoken_languages    status  \
# 0      2/20/15    93.0  [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 1       8/6/04   113.0  [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 2     10/10/14   105.0  [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 5       8/6/87    83.0  [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 6      8/30/12    92.0  [{'iso_639_1': 'en', 'name': 'English'}]  Released
#
#                                              tagline  \
# 0  The Laws of Space and Time are About to be Vio...
# 1  It can take a lifetime to find true love; she'...
# 2    The road to greatness can take you to the edge.
# 5                                                NaN
# 6               Fear The Demon That Doesn't Fear God
#
#                                       title  \
# 0                    Hot Tub Time Machine 2
# 1  The Princess Diaries 2: Royal Engagement
# 2                                  Whiplash
# 5    Pinocchio and the Emperor of the Night
# 6                            The Possession
#
#                                             Keywords  \
# 0  [{'id': 4379, 'name': 'time travel'}, {'id': 9...
# 1  [{'id': 2505, 'name': 'coronation'}, {'id': 42...
# 2  [{'id': 1416, 'name': 'jazz'}, {'id': 1523, 'n...
# 5                                                NaN
# 6                                                NaN
#
#                                                 cast  \
# 0  [{'cast_id': 4, 'character': 'Lou', 'credit_id...
# 1  [{'cast_id': 1, 'character': 'Mia Thermopolis'...
# 2  [{'cast_id': 5, 'character': 'Andrew Neimann',...
# 5  [{'cast_id': 6, 'character': 'Pinocchio (voice...
# 6  [{'cast_id': 23, 'character': 'Clyde', 'credit...
#
#                                                 crew   revenue
# 0  [{'credit_id': '59ac067c92514107af02c8c8', 'de...  12314651
# 1  [{'credit_id': '52fe43fe9251416c7502563d', 'de...  95149435
# 2  [{'credit_id': '54d5356ec3a3683ba0000039', 'de...  13092000
# 5  [{'credit_id': '52fe46f49251416c9106558b', 'de...   3261638
# 6  [{'credit_id': '52fe4981c3a368484e12ee29', 'de...  85446075
#
# [5 rows x 23 columns]

# %%
long_movies.head()
# Out:
#      imdb_id original_language
# 1  tt0368933                en
# 2  tt2582802                en
# 3  tt1821480                hi
# 4  tt1380152                ko
# 8  tt0117110                en

# %%
long_movies = imdb_df[imdb_df['runtime'] >= 100][['imdb_id','original_language']]
long_movies.head()
# Out:
#      imdb_id original_language
# 1  tt0368933                en
# 2  tt2582802                en
# 3  tt1821480                hi
# 4  tt1380152                ko
# 8  tt0117110                en

# %% [markdown]
# 🎥👨‍💻 The first line of code creates a new DataFrame called english_movies by selecting only the rows from imdb_df where the value in the original_language column is equal to 'en', which represents English movies. This is achieved by using a boolean mask that checks if the value in the original_language column is equal to 'en'.
#
# 🕰️🎞️ The second line of code creates another new DataFrame called long_movies. This DataFrame is created by selecting only the rows from imdb_df where the value in the runtime column is greater than or equal to 100. Additionally, we only select two columns from the original DataFrame, imdb_id and original_language, by using the .loc accessor and passing in the boolean mask for runtime and a list of column names to select.

# %%
english_movies.shape, long_movies.shape
# Out:
# ((2575, 23), (1820, 2))

# %% [markdown]
# ### <B> Using **Inner Join** to merge the two dataframes

# %% [markdown]
# An inner join 🤝 refers to the process of combining two dataframes based on the values of a common column 🔗, and only keeping the rows where there is a match 🎯 between the values in that column in both dataframes.

# %% [markdown]
# ![PostgreSQL-Join-Inner-Join.png](data:image/png;base64,...)

# %% [markdown]
# Here is how? 👇

# %%
merged_IJ_df = pd.merge(english_movies,long_movies,how='inner',left_on='imdb_id',right_on='imdb_id')
merged_IJ_df.head()
# Out:
#    id                              belongs_to_collection    budget  \
# 0   2  [{'id': 107674, 'name': 'The Princess Diaries ...  40000000
# 1   3                                                NaN   3300000
# 2   9  [{'id': 256377, 'name': 'The Muppet Collection...         0
# 3  11  [{'id': 1575, 'name': 'Rocky Collection', 'pos...   1000000
# 4  13                                                NaN  15000000
#
#                                               genres  \
# 0  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 1                      [{'id': 18, 'name': 'Drama'}]
# 2  [{'id': 28, 'name': 'Action'}, {'id': 35, 'nam...
# 3                      [{'id': 18, 'name': 'Drama'}]
# 4                      [{'id': 18, 'name': 'Drama'}]
#
#                             homepage    imdb_id original_language_x  \
# 0                                NaN  tt0368933                  en
# 1  http://sonyclassics.com/whiplash/  tt2582802                  en
# 2                                NaN  tt0117110                  en
# 3                                NaN  tt0075148                  en
# 4      http://www.dreamworks.com/ab/  tt0169547                  en
#
#                              original_title  \
# 0  The Princess Diaries 2: Royal Engagement
# 1                                  Whiplash
# 2                    Muppet Treasure Island
# 3                                     Rocky
# 4                           American Beauty
#
#                                             overview  popularity  ... runtime  \
# 0  Mia Thermopolis is now a college graduate and ...    8.248895  ...   113.0
# 1  Under the direction of a ruthless instructor, ...   64.299990  ...   105.0
# 2  After telling the story of Flint's last journe...    6.902423  ...   100.0
# 3  When world heavyweight boxing champion, Apollo...   14.774066  ...   119.0
# 4  Lester Burnham, a depressed suburban father in...   20.726578  ...   122.0
#
#                            spoken_languages    status  \
# 0  [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 1  [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 2  [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 3  [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 4  [{'iso_639_1': 'en', 'name': 'English'}]  Released
#
#                                              tagline  \
# 0  It can take a lifetime to find true love; she'...
# 1    The road to greatness can take you to the edge.
# 2                        Set sail for Muppet mayhem!
# 3          His whole life was a million-to-one shot.
# 4                                       Look closer.
#
#                                       title  \
# 0  The Princess Diaries 2: Royal Engagement
# 1                                  Whiplash
# 2                    Muppet Treasure Island
# 3                                     Rocky
# 4                           American Beauty
#
#                                             Keywords  \
# 0  [{'id': 2505, 'name': 'coronation'}, {'id': 42...
# 1  [{'id': 1416, 'name': 'jazz'}, {'id': 1523, 'n...
# 2  [{'id': 2041, 'name': 'island'}, {'id': 4418, ...
# 3  [{'id': 240, 'name': 'underdog'}, {'id': 276, ...
# 4  [{'id': 255, 'name': 'male nudity'}, {'id': 29...
#
#                                                 cast  \
# 0  [{'cast_id': 1, 'character': 'Mia Thermopolis'...
# 1  [{'cast_id': 5, 'character': 'Andrew Neimann',...
# 2  [{'cast_id': 1, 'character': 'Long John Silver...
# 3  [{'cast_id': 16, 'character': 'Rocky Balboa', ...
# 4  [{'cast_id': 6, 'character': 'Lester Burnham',...
#
#                                                 crew    revenue  \
# 0  [{'credit_id': '52fe43fe9251416c7502563d', 'de...   95149435
# 1  [{'credit_id': '54d5356ec3a3683ba0000039', 'de...   13092000
# 2  [{'credit_id': '52fe43c89251416c7501deb3', 'de...   34327391
# 3  [{'credit_id': '579948e9c3a36874e9007b0b', 'de...  117235147
# 4  [{'credit_id': '52fe420ec3a36847f80007c5', 'de...  356296601
#
#   original_language_y
# 0                  en
# 1                  en
# 2                  en
# 3                  en
# 4                  en
#
# [5 rows x 24 columns]

# %%
merged_IJ_df['runtime'].min()
# Out:
# 100.0

# %% [markdown]
# This code is merging two pandas dataframes, english_movies and long_movies, based on the shared column imdb_id. The resulting merged dataframe will contain only the rows that have matching imdb_id values in both input dataframes.
#
# The how='inner' parameter specifies that an inner join should be used, meaning only the rows that have matching imdb_id values in both dataframes will be included in the merged dataframe.
#
# The left_on='imdb_id' and right_on='imdb_id' parameters specify that the join should be based on the imdb_id column in both dataframes, as this is the shared column that will be used to match rows between the two dataframes.
#
# The resulting dataframe merged_IJ_df will have the columns from both dataframes but only the rows that had matching imdb_id values.

# %%
merged_IJ_df['runtime'].min()
# Out:
# 100.0

# %%
merged_IJ_df
# Out:
#         id                              belongs_to_collection    budget  \
# 0        2  [{'id': 107674, 'name': 'The Princess Diaries ...  40000000
# 1        3                                                NaN   3300000
# 2        9  [{'id': 256377, 'name': 'The Muppet Collection...         0
# 3       11  [{'id': 1575, 'name': 'Rocky Collection', 'pos...   1000000
# 4       13                                                NaN  15000000
# ...    ...                                                ...       ...
# 1523  2994                                                NaN  60000000
# 1524  2995                                                NaN         0
# 1525  2996                                                NaN         0
# 1526  2998                                                NaN  65000000
# 1527  3000                                                NaN  35000000
#
#                                                  genres  \
# 0     [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 1                         [{'id': 18, 'name': 'Drama'}]
# 2     [{'id': 28, 'name': 'Action'}, {'id': 35, 'nam...
# 3                         [{'id': 18, 'name': 'Drama'}]
# 4                         [{'id': 18, 'name': 'Drama'}]
# ...                                                 ...
# 1523  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 1524                      [{'id': 18, 'name': 'Drama'}]
# 1525  [{'id': 35, 'name': 'Comedy'}, {'id': 10749, '...
# 1526  [{'id': 80, 'name': 'Crime'}, {'id': 28, 'name...
# 1527  [{'id': 53, 'name': 'Thriller'}, {'id': 28, 'n...
#
#                                   homepage    imdb_id original_language_x  \
# 0                                      NaN  tt0368933                  en
# 1        http://sonyclassics.com/whiplash/  tt2582802                  en
# 2                                      NaN  tt0117110                  en
# 3                                      NaN  tt0075148                  en
# 4            http://www.dreamworks.com/ab/  tt0169547                  en
# ...                                    ...        ...                 ...
# 1523  http://www.theterminal-themovie.com/  tt0362227                  en
# 1524                                   NaN  tt0105327                  en
# 1525                                   NaN  tt0109403                  en
# 1526                                   NaN  tt0116908                  en
# 1527      http://www.abductionthefilm.com/  tt1600195                  en
#
#                                 original_title  \
# 0     The Princess Diaries 2: Royal Engagement
# 1                                     Whiplash
# 2                       Muppet Treasure Island
# 3                                        Rocky
# 4                              American Beauty
# ...                                        ...
# 1523                              The Terminal
# 1524                               School Ties
# 1525                                   Chasers
# 1526                   The Long Kiss Goodnight
# 1527                                 Abduction
#
#                                                overview  popularity  ...  \
# 0     Mia Thermopolis is now a college graduate and ...    8.248895  ...
# 1     Under the direction of a ruthless instructor, ...   64.299990  ...
# 2     After telling the story of Flint's last journe...    6.902423  ...
# 3     When world heavyweight boxing champion, Apollo...   14.774066  ...
# 4     Lester Burnham, a depressed suburban father in...   20.726578  ...
# ...                                                 ...         ...  ...
# 1523  Viktor Navorski is a man without a country; hi...   14.092373  ...
# 1524  When David Greene receives a football scholars...    7.438381  ...
# 1525  Military men Rock Reilly and Eddie Devane are ...    9.853270  ...
# 1526  Samantha Caine, suburban homemaker, is the ide...   14.482345  ...
# 1527  A young man sets out to uncover the truth abou...   10.512109  ...
#
#      runtime                                   spoken_languages    status  \
# 0      113.0           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 1      105.0           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 2      100.0           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 3      119.0           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 4      122.0           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# ...      ...                                                ...       ...
# 1523   128.0  [{'iso_639_1': 'bg', 'name': 'български език'}...  Released
# 1524   106.0           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 1525   102.0           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 1526   120.0           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 1527   106.0           [{'iso_639_1': 'en', 'name': 'English'}]  Released
#
#                                                 tagline  \
# 0     It can take a lifetime to find true love; she'...
# 1       The road to greatness can take you to the edge.
# 2                           Set sail for Muppet mayhem!
# 3             His whole life was a million-to-one shot.
# 4                                          Look closer.
# ...                                                 ...
# 1523                                   Life is waiting.
# 1524  Just because you’re accepted doesn’t mean you ...
# 1525  It was supposed to be a routine prisoner trans...
# 1526               What's forgotten is not always gone.
# 1527          They stole his life. He's taking it back.
#
#                                          title  \
# 0     The Princess Diaries 2: Royal Engagement
# 1                                     Whiplash
# 2                       Muppet Treasure Island
# 3                                        Rocky
# 4                              American Beauty
# ...                                        ...
# 1523                              The Terminal
# 1524                               School Ties
# 1525                                   Chasers
# 1526                   The Long Kiss Goodnight
# 1527                                 Abduction
#
#                                                Keywords  \
# 0     [{'id': 2505, 'name': 'coronation'}, {'id': 42...
# 1     [{'id': 1416, 'name': 'jazz'}, {'id': 1523, 'n...
# 2     [{'id': 2041, 'name': 'island'}, {'id': 4418, ...
# 3     [{'id': 240, 'name': 'underdog'}, {'id': 276, ...
# 4     [{'id': 255, 'name': 'male nudity'}, {'id': 29...
# ...                                                 ...
# 1523  [{'id': 242, 'name': 'new york'}, {'id': 822, ...
# 1524  [{'id': 6075, 'name': 'sport'}, {'id': 10144, ...
# 1525  [{'id': 378, 'name': 'prison'}, {'id': 572, 'n...
# 1526  [{'id': 441, 'name': 'assassination'}, {'id': ...
# 1527  [{'id': 591, 'name': 'cia'}, {'id': 822, 'name...
#
#                                                    cast  \
# 0     [{'cast_id': 1, 'character': 'Mia Thermopolis'...
# 1     [{'cast_id': 5, 'character': 'Andrew Neimann',...
# 2     [{'cast_id': 1, 'character': 'Long John Silver...
# 3     [{'cast_id': 16, 'character': 'Rocky Balboa', ...
# 4     [{'cast_id': 6, 'character': 'Lester Burnham',...
# ...                                                 ...
# 1523  [{'cast_id': 4, 'character': 'Viktor Navorski'...
# 1524  [{'cast_id': 2, 'character': 'David Greene', '...
# 1525  [{'cast_id': 2, 'character': 'Rock Reilly', 'c...
# 1526  [{'cast_id': 10, 'character': 'Samantha Caine ...
# 1527  [{'cast_id': 2, 'character': 'Nathan Harper', ...
#
#                                                    crew    revenue  \
# 0     [{'credit_id': '52fe43fe9251416c7502563d', 'de...   95149435
# 1     [{'credit_id': '54d5356ec3a3683ba0000039', 'de...   13092000
# 2     [{'credit_id': '52fe43c89251416c7501deb3', 'de...   34327391
# 3     [{'credit_id': '579948e9c3a36874e9007b0b', 'de...  117235147
# 4     [{'credit_id': '52fe420ec3a36847f80007c5', 'de...  356296601
# ...                                                 ...        ...
# 1523  [{'credit_id': '52fe4259c3a36847f8017699', 'de...  219417255
# 1524  [{'credit_id': '5637777ac3a3681b4d01f9f5', 'de...   14715067
# 1525  [{'credit_id': '52fe4494c3a368484e02ac7d', 'de...    1596687
# 1526  [{'credit_id': '52fe443a9251416c7502d579', 'de...   89456761
# 1527  [{'credit_id': '5391990d0e0a260fb5001629', 'de...   82087155
#
#      original_language_y
# 0                     en
# 1                     en
# 2                     en
# 3                     en
# 4                     en
# ...                  ...
# 1523                  en
# 1524                  en
# 1525                  en
# 1526                  en
# 1527                  en
#
# [1528 rows x 24 columns]

# %% [markdown]
# ### <b> Using left join to merge the two dataframes

# %% [markdown]
# 🤔🔍 When it comes to code, performing a left join in Pandas requires using the .merge() method and specifying the left and right dataframes, the common key(s) to merge on, and the type of join to perform (in this case, how='left').
#
# 🤝💻 This process compares the common key(s) in the left and right dataframes and returns a new dataframe that includes all the rows from the left dataframe and the matching rows from the right dataframe.
#
# 💡📊 However, for any non-matching rows, the columns corresponding to the right dataframe will have null values in the resulting dataframe.

# %% [markdown]
# ![lrf.png](data:image/png;base64,...)

# %% [markdown]
# Let's perform left join 👇

# %%
# Merging the two dataframes using left join
merged_LJ_df = pd.merge(english_movies, long_movies, how='left',left_on='imdb_id',right_on='imdb_id')

# %% [markdown]
# This code performs a left join on two dataframes english_movies and long_movies using the **.merge()** method in Pandas.
#
# The resulting merged dataframe is assigned to **merged_LJ_df**.
#
# The **how='left'** parameter specifies that we want to perform a left join, which will include all rows from the left dataframe **(english_movies)** and only matching rows from the right dataframe **(long_movies).**
#
# The **left_on** and **right_on** parameters specify the column(s) to use as keys for the join operation. In this case, the **imdb_id** column is used as the common key for both dataframes.
#
# By using the left join, we retain all rows from **english_movies** and only include matching rows from **long_movies**, while replacing non-matching rows with null values in the columns corresponding to **long_movies**.

# %%
merged_LJ_df.isnull()
# Out:
#          id  belongs_to_collection  budget  genres  homepage  imdb_id  \
# 0     False                  False   False   False      True    False
# 1     False                  False   False   False      True    False
# 2     False                   True   False   False     False    False
# 3     False                   True   False   False      True    False
# 4     False                   True   False   False     False    False
# ...     ...                    ...     ...     ...       ...      ...
# 2570  False                   True   False   False      True    False
# 2571  False                   True   False   False      True    False
# 2572  False                   True   False   False      True    False
# 2573  False                   True   False   False     False    False
# 2574  False                   True   False   False     False    False
#
#       original_language_x  original_title  overview  popularity  ...  runtime  \
# 0                   False           False     False       False  ...    False
# 1                   False           False     False       False  ...    False
# 2                   False           False     False       False  ...    False
# 3                   False           False     False       False  ...    False
# 4                   False           False     False       False  ...    False
# ...                   ...             ...       ...         ...  ...      ...
# 2570                False           False     False       False  ...    False
# 2571                False           False     False       False  ...    False
# 2572                False           False     False       False  ...    False
# 2573                False           False     False       False  ...    False
# 2574                False           False     False       False  ...    False
#
#       spoken_languages  status  tagline  title  Keywords   cast   crew  \
# 0                False   False    False  False     False  False  False
# 1                False   False    False  False     False  False  False
# 2                False   False    False  False     False  False  False
# 3                False   False     True  False      True  False  False
# 4                False   False    False  False      True  False  False
# ...                ...     ...      ...    ...       ...    ...    ...
# 2570             False   False    False  False     False  False  False
# 2571             False   False    False  False     False  False  False
# 2572             False   False    False  False     False  False  False
# 2573             False   False    False  False     False  False  False
# 2574             False   False    False  False     False  False  False
#
#       revenue  original_language_y
# 0       False                 True
# 1       False                False
# 2       False                False
# 3       False                 True
# 4       False                 True
# ...       ...                  ...
# 2570    False                False
# 2571    False                False
# 2572    False                False
# 2573    False                 True
# 2574    False                False
#
# [2575 rows x 24 columns]

# %% [markdown]
# ### <b> Using right join to merge the two dataframes

# %% [markdown]
# 🧐🔗 A right join, also known as a right outer join, is a type of join operation that is used to combine two dataframes based on a common key, but it includes all rows from the right dataframe and only the matching rows from the left dataframe.
#
# In other words, a right join returns all the rows from the right dataframe and fills in any matching rows from the left dataframe, and replaces any non-matching rows from the left dataframe with null values.
#
# To perform a right join in pandas, you can use the .merge() method and specify the right and left dataframes, the common key(s) to merge on, and the type of join to perform (in this case, how='right'). 🤝💻

# %% [markdown]
# ![ryt.png](data:image/png;base64,...)

# %%
merged_RJ_df= pd.merge(english_movies,long_movies,how='right',left_on='imdb_id',right_on='imdb_id')
merged_RJ_df
# Out:
#           id                              belongs_to_collection      budget  \
# 0        2.0  [{'id': 107674, 'name': 'The Princess Diaries ...  40000000.0
# 1        3.0                                                NaN   3300000.0
# 2        NaN                                                NaN         NaN
# 3        NaN                                                NaN         NaN
# 4        9.0  [{'id': 256377, 'name': 'The Muppet Collection...         0.0
# ...      ...                                                ...         ...
# 1815  2995.0                                                NaN         0.0
# 1816  2996.0                                                NaN         0.0
# 1817     NaN                                                NaN         NaN
# 1818  2998.0                                                NaN  65000000.0
# 1819  3000.0                                                NaN  35000000.0
#
#                                                  genres  \
# 0     [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 1                         [{'id': 18, 'name': 'Drama'}]
# 2                                                   NaN
# 3                                                   NaN
# 4     [{'id': 28, 'name': 'Action'}, {'id': 35, 'nam...
# ...                                                 ...
# 1815                      [{'id': 18, 'name': 'Drama'}]
# 1816  [{'id': 35, 'name': 'Comedy'}, {'id': 10749, '...
# 1817                                                NaN
# 1818  [{'id': 80, 'name': 'Crime'}, {'id': 28, 'name...
# 1819  [{'id': 53, 'name': 'Thriller'}, {'id': 28, 'n...
#
#                                homepage    imdb_id original_language_x  \
# 0                                   NaN  tt0368933                  en
# 1     http://sonyclassics.com/whiplash/  tt2582802                  en
# 2                                   NaN  tt1821480                 NaN
# 3                                   NaN  tt1380152                 NaN
# 4                                   NaN  tt0117110                  en
# ...                                 ...        ...                 ...
# 1815                                NaN  tt0105327                  en
# 1816                                NaN  tt0109403                  en
# 1817                                NaN  tt2364975                 NaN
# 1818                                NaN  tt0116908                  en
# 1819   http://www.abductionthefilm.com/  tt1600195                  en
#
#                                 original_title  \
# 0     The Princess Diaries 2: Royal Engagement
# 1                                     Whiplash
# 2                                          NaN
# 3                                          NaN
# 4                       Muppet Treasure Island
# ...                                        ...
# 1815                               School Ties
# 1816                                   Chasers
# 1817                                       NaN
# 1818                   The Long Kiss Goodnight
# 1819                                 Abduction
#
#                                                overview  popularity  ...  \
# 0     Mia Thermopolis is now a college graduate and ...    8.248895  ...
# 1     Under the direction of a ruthless instructor, ...   64.299990  ...
# 2                                                   NaN         NaN  ...
# 3                                                   NaN         NaN  ...
# 4     After telling the story of Flint's last journe...    6.902423  ...
# ...                                                 ...         ...  ...
# 1815  When David Greene receives a football scholars...    7.438381  ...
# 1816  Military men Rock Reilly and Eddie Devane are ...    9.853270  ...
# 1817                                                NaN         NaN  ...
# 1818  Samantha Caine, suburban homemaker, is the ide...   14.482345  ...
# 1819  A young man sets out to uncover the truth abou...   10.512109  ...
#
#      runtime                          spoken_languages    status  \
# 0      113.0  [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 1      105.0  [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 2        NaN                                       NaN       NaN
# 3        NaN                                       NaN       NaN
# 4      100.0  [{'iso_639_1': 'en', 'name': 'English'}]  Released
# ...      ...                                       ...       ...
# 1815   106.0  [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 1816   102.0  [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 1817     NaN                                       NaN       NaN
# 1818   120.0  [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 1819   106.0  [{'iso_639_1': 'en', 'name': 'English'}]  Released
#
#                                                 tagline  \
# 0     It can take a lifetime to find true love; she'...
# 1       The road to greatness can take you to the edge.
# 2                                                   NaN
# 3                                                   NaN
# 4                           Set sail for Muppet mayhem!
# ...                                                 ...
# 1815  Just because you’re accepted doesn’t mean you ...
# 1816  It was supposed to be a routine prisoner trans...
# 1817                                                NaN
# 1818               What's forgotten is not always gone.
# 1819          They stole his life. He's taking it back.
#
#                                          title  \
# 0     The Princess Diaries 2: Royal Engagement
# 1                                     Whiplash
# 2                                          NaN
# 3                                          NaN
# 4                       Muppet Treasure Island
# ...                                        ...
# 1815                               School Ties
# 1816                                   Chasers
# 1817                                       NaN
# 1818                   The Long Kiss Goodnight
# 1819                                 Abduction
#
#                                                Keywords  \
# 0     [{'id': 2505, 'name': 'coronation'}, {'id': 42...
# 1     [{'id': 1416, 'name': 'jazz'}, {'id': 1523, 'n...
# 2                                                   NaN
# 3                                                   NaN
# 4     [{'id': 2041, 'name': 'island'}, {'id': 4418, ...
# ...                                                 ...
# 1815  [{'id': 6075, 'name': 'sport'}, {'id': 10144, ...
# 1816  [{'id': 378, 'name': 'prison'}, {'id': 572, 'n...
# 1817                                                NaN
# 1818  [{'id': 441, 'name': 'assassination'}, {'id': ...
# 1819  [{'id': 591, 'name': 'cia'}, {'id': 822, 'name...
#
#                                                    cast  \
# 0     [{'cast_id': 1, 'character': 'Mia Thermopolis'...
# 1     [{'cast_id': 5, 'character': 'Andrew Neimann',...
# 2                                                   NaN
# 3                                                   NaN
# 4     [{'cast_id': 1, 'character': 'Long John Silver...
# ...                                                 ...
# 1815  [{'cast_id': 2, 'character': 'David Greene', '...
# 1816  [{'cast_id': 2, 'character': 'Rock Reilly', 'c...
# 1817                                                NaN
# 1818  [{'cast_id': 10, 'character': 'Samantha Caine ...
# 1819  [{'cast_id': 2, 'character': 'Nathan Harper', ...
#
#                                                    crew     revenue  \
# 0     [{'credit_id': '52fe43fe9251416c7502563d', 'de...  95149435.0
# 1     [{'credit_id': '54d5356ec3a3683ba0000039', 'de...  13092000.0
# 2                                                   NaN         NaN
# 3                                                   NaN         NaN
# 4     [{'credit_id': '52fe43c89251416c7501deb3', 'de...  34327391.0
# ...                                                 ...         ...
# 1815  [{'credit_id': '5637777ac3a3681b4d01f9f5', 'de...  14715067.0
# 1816  [{'credit_id': '52fe4494c3a368484e02ac7d', 'de...   1596687.0
# 1817                                                NaN         NaN
# 1818  [{'credit_id': '52fe443a9251416c7502d579', 'de...  89456761.0
# 1819  [{'credit_id': '5391990d0e0a260fb5001629', 'de...  82087155.0
#
#      original_language_y
# 0                     en
# 1                     en
# 2                     hi
# 3                     ko
# 4                     en
# ...                  ...
# 1815                  en
# 1816                  en
# 1817                  sv
# 1818                  en
# 1819                  en
#
# [1820 rows x 24 columns]

# %% [markdown]
# This code performs a right join on two dataframes **english_movies** and **long_movies** using the **.merge()** method in Pandas.
#
# The resulting merged dataframe is assigned to **merged_RJ_df**.
#
# The **how='right'** parameter specifies that we want to perform a right join, which will include all rows from the right dataframe **(long_movies)** and only matching rows from the left dataframe **(english_movies)**.
#
# The **left_on** and **right_on** parameters specify the column(s) to use as keys for the join operation. In this case, the **imdb_id** column is used as the common key for both dataframes.
#
# By using the right join, we retain all rows from **long_movies** and only include matching rows from **english_movies**, while replacing non-matching rows from english_movies with null values.

# %%
merged_RJ_df
# Out:
#           id                              belongs_to_collection      budget  \
# 0        2.0  [{'id': 107674, 'name': 'The Princess Diaries ...  40000000.0
# 1        3.0                                                NaN   3300000.0
# 2        NaN                                                NaN         NaN
# 3        NaN                                                NaN         NaN
# 4        9.0  [{'id': 256377, 'name': 'The Muppet Collection...         0.0
# ...      ...                                                ...         ...
# 1815  2995.0                                                NaN         0.0
# 1816  2996.0                                                NaN         0.0
# 1817     NaN                                                NaN         NaN
# 1818  2998.0                                                NaN  65000000.0
# 1819  3000.0                                                NaN  35000000.0
#
#                                                  genres  \
# 0     [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 1                         [{'id': 18, 'name': 'Drama'}]
# 2                                                   NaN
# 3                                                   NaN
# 4     [{'id': 28, 'name': 'Action'}, {'id': 35, 'nam...
# ...                                                 ...
# 1815                      [{'id': 18, 'name': 'Drama'}]
# 1816  [{'id': 35, 'name': 'Comedy'}, {'id': 10749, '...
# 1817                                                NaN
# 1818  [{'id': 80, 'name': 'Crime'}, {'id': 28, 'name...
# 1819  [{'id': 53, 'name': 'Thriller'}, {'id': 28, 'n...
#
#                                homepage    imdb_id original_language_x  \
# 0                                   NaN  tt0368933                  en
# 1     http://sonyclassics.com/whiplash/  tt2582802                  en
# 2                                   NaN  tt1821480                 NaN
# 3                                   NaN  tt1380152                 NaN
# 4                                   NaN  tt0117110                  en
# ...                                 ...        ...                 ...
# 1815                                NaN  tt0105327                  en
# 1816                                NaN  tt0109403                  en
# 1817                                NaN  tt2364975                 NaN
# 1818                                NaN  tt0116908                  en
# 1819   http://www.abductionthefilm.com/  tt1600195                  en
#
#                                 original_title  \
# 0     The Princess Diaries 2: Royal Engagement
# 1                                     Whiplash
# 2                                          NaN
# 3                                          NaN
# 4                       Muppet Treasure Island
# ...                                        ...
# 1815                               School Ties
# 1816                                   Chasers
# 1817                                       NaN
# 1818                   The Long Kiss Goodnight
# 1819                                 Abduction
#
#                                                overview  popularity  ...  \
# 0     Mia Thermopolis is now a college graduate and ...    8.248895  ...
# 1     Under the direction of a ruthless instructor, ...   64.299990  ...
# 2                                                   NaN         NaN  ...
# 3                                                   NaN         NaN  ...
# 4     After telling the story of Flint's last journe...    6.902423  ...
# ...                                                 ...         ...  ...
# 1815  When David Greene receives a football scholars...    7.438381  ...
# 1816  Military men Rock Reilly and Eddie Devane are ...    9.853270  ...
# 1817                                                NaN         NaN  ...
# 1818  Samantha Caine, suburban homemaker, is the ide...   14.482345  ...
# 1819  A young man sets out to uncover the truth abou...   10.512109  ...
#
#      runtime                          spoken_languages    status  \
# 0      113.0  [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 1      105.0  [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 2        NaN                                       NaN       NaN
# 3        NaN                                       NaN       NaN
# 4      100.0  [{'iso_639_1': 'en', 'name': 'English'}]  Released
# ...      ...                                       ...       ...
# 1815   106.0  [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 1816   102.0  [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 1817     NaN                                       NaN       NaN
# 1818   120.0  [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 1819   106.0  [{'iso_639_1': 'en', 'name': 'English'}]  Released
#
#                                                 tagline  \
# 0     It can take a lifetime to find true love; she'...
# 1       The road to greatness can take you to the edge.
# 2                                                   NaN
# 3                                                   NaN
# 4                           Set sail for Muppet mayhem!
# ...                                                 ...
# 1815  Just because you’re accepted doesn’t mean you ...
# 1816  It was supposed to be a routine prisoner trans...
# 1817                                                NaN
# 1818               What's forgotten is not always gone.
# 1819          They stole his life. He's taking it back.
#
#                                          title  \
# 0     The Princess Diaries 2: Royal Engagement
# 1                                     Whiplash
# 2                                          NaN
# 3                                          NaN
# 4                       Muppet Treasure Island
# ...                                        ...
# 1815                               School Ties
# 1816                                   Chasers
# 1817                                       NaN
# 1818                   The Long Kiss Goodnight
# 1819                                 Abduction
#
#                                                Keywords  \
# 0     [{'id': 2505, 'name': 'coronation'}, {'id': 42...
# 1     [{'id': 1416, 'name': 'jazz'}, {'id': 1523, 'n...
# 2                                                   NaN
# 3                                                   NaN
# 4     [{'id': 2041, 'name': 'island'}, {'id': 4418, ...
# ...                                                 ...
# 1815  [{'id': 6075, 'name': 'sport'}, {'id': 10144, ...
# 1816  [{'id': 378, 'name': 'prison'}, {'id': 572, 'n...
# 1817                                                NaN
# 1818  [{'id': 441, 'name': 'assassination'}, {'id': ...
# 1819  [{'id': 591, 'name': 'cia'}, {'id': 822, 'name...
#
#                                                    cast  \
# 0     [{'cast_id': 1, 'character': 'Mia Thermopolis'...
# 1     [{'cast_id': 5, 'character': 'Andrew Neimann',...
# 2                                                   NaN
# 3                                                   NaN
# 4     [{'cast_id': 1, 'character': 'Long John Silver...
# ...                                                 ...
# 1815  [{'cast_id': 2, 'character': 'David Greene', '...
# 1816  [{'cast_id': 2, 'character': 'Rock Reilly', 'c...
# 1817                                                NaN
# 1818  [{'cast_id': 10, 'character': 'Samantha Caine ...
# 1819  [{'cast_id': 2, 'character': 'Nathan Harper', ...
#
#                                                    crew     revenue  \
# 0     [{'credit_id': '52fe43fe9251416c7502563d', 'de...  95149435.0
# 1     [{'credit_id': '54d5356ec3a3683ba0000039', 'de...  13092000.0
# 2                                                   NaN         NaN
# 3                                                   NaN         NaN
# 4     [{'credit_id': '52fe43c89251416c7501deb3', 'de...  34327391.0
# ...                                                 ...         ...
# 1815  [{'credit_id': '5637777ac3a3681b4d01f9f5', 'de...  14715067.0
# 1816  [{'credit_id': '52fe4494c3a368484e02ac7d', 'de...   1596687.0
# 1817                                                NaN         NaN
# 1818  [{'credit_id': '52fe443a9251416c7502d579', 'de...  89456761.0
# 1819  [{'credit_id': '5391990d0e0a260fb5001629', 'de...  82087155.0
#
#      original_language_y
# 0                     en
# 1                     en
# 2                     hi
# 3                     ko
# 4                     en
# ...                  ...
# 1815                  en
# 1816                  en
# 1817                  sv
# 1818                  en
# 1819                  en
#
# [1820 rows x 24 columns]

# %% [markdown]
# ### <b> Using outer join to merge the two dataframes

# %% [markdown]
# ![fyll.png](data:image/png;base64,...)

# %% [markdown]
# 🔍🤔 An outer join, also known as a full outer join, is a type of join operation used to combine two dataframes based on a common key(s). In an outer join, all rows from both dataframes are included in the resulting dataframe, regardless of whether there is a match or not.
#
# 💻 In Pandas, you can perform an outer join using the .merge() method and specifying the left and right dataframes, the common key(s) to merge on, and the type of join to perform (in this case, how='outer').
#
# 🧐 The resulting dataframe will have all the rows from both dataframes, with null or NaN values in the columns corresponding to any non-matching rows.

# %%
# Outer Join
merged_OJ_df = pd.merge(english_movies[['imdb_id','runtime']],long_movies, on='imdb_id', how='outer')

# %% [markdown]
# This code performs an outer join on two dataframes **english_movies** and **long_movies** using the **.merge()** method in Pandas.
#
# The  **[ ['imdb_id','runtime'] ]** syntax is used to subset the columns in the **english_movies** dataframe to only include the **imdb_id** and runtime columns. This subset dataframe is used as the left dataframe in the join operation.
#
# The **on='imdb_id'** parameter specifies that we want to perform the join on the **imdb_id** column, which is the common key between the two dataframes.
#
# The **how='outer'** parameter specifies that we want to perform an outer join, which will include all rows from both dataframes, regardless of whether there is a match or not.
#
# The resulting merged dataframe is assigned to **merged_OJ_df**.
#
# The resulting dataframe will have all the rows from both dataframes, with **null** or **NaN** values in the columns corresponding to any non-matching rows.

# %%
merged_OJ_df
# Out:
#         imdb_id  runtime original_language
# 0     tt2637294     93.0               NaN
# 1     tt0368933    113.0                en
# 2     tt2582802    105.0                en
# 3     tt0093743     83.0               NaN
# 4     tt0431021     92.0               NaN
# ...         ...      ...               ...
# 2862  tt2106741      NaN                zh
# 2863  tt1093370      NaN                hi
# 2864  tt1194664      NaN                ja
# 2865  tt5320514      NaN                ml
# 2866  tt2364975      NaN                sv
#
# [2867 rows x 3 columns]

# %% [markdown]
# ## <b> Activity 3:

# %% [markdown]
# 🎬 Imagine you're working for a movie production company that wants to analyze trends in high-budget movies 💰. Your task is to create a dataset of all movies released in the year 2013 🗓️ and another dataframe of movies with a budget greater than 20 million 💸. Then, you need to join the two dataframes using an inner join to get a list of high-budget movies that were released in 2013.
#
# 📊 Your deliverable will be a new dataframe containing all the relevant information of high-budget movies released in 2013 📈. This dataset will be used by your team to inform decisions about future movie production budgets and marketing strategies 🤑.
#
# Good luck 🍀, and remember to use the powerful pandas library 🐼 to efficiently manipulate and analyze the data!

# %% [markdown]
# **Note: The release_date field in the dataset is in string format and needs to be converted to datetime format. To do this we will be using datetime module in python which you will learn about going forward. For the time being, you can run the following code to create another column with release_year in it**

# %%
imdb_df['release_year'] = pd.to_datetime(imdb_df['release_date']).dt.year
imdb_df['release_year']
# Out:
# 0       2015
# 1       2004
# 2       2014
# 3       2012
# 4       2009
#         ...
# 2995    1994
# 2996    2013
# 2997    1996
# 2998    2004
# 2999    2011
# Name: release_year, Length: 3000, dtype: int64

# %%
from datetime import datetime

imdb_df['release_year'] = pd.to_datetime(imdb_df['release_date']).dt.year

# %%
movie_2013 = imdb_df[imdb_df['release_year']==2013]
high_budget = imdb_df[imdb_df['budget']>20000000][['id','budget']]
high_bud_2013 = pd.merge(movie_2013,high_budget,on='id',how='inner')
high_bud_2013.sort_values('budget_y',ascending = True ,inplace=True)
high_bud_2013[['release_year', 'budget_y','budget_x']]
# Out:
#     release_year   budget_y   budget_x
# 15          2013   22000000   22000000
# 42          2013   25000000   25000000
# 11          2013   25000000   25000000
# 17          2013   25000000   25000000
# 25          2013   27220000   27220000
# 33          2013   28000000   28000000
# 29          2013   28000000   28000000
# 6           2013   28000000   28000000
# 9           2013   28000000   28000000
# 28          2013   30000000   30000000
# 21          2013   30000000   30000000
# 22          2013   32000000   32000000
# 2           2013   35000000   35000000
# 7           2013   35000000   35000000
# 19          2013   35000000   35000000
# 13          2013   35000000   35000000
# 0           2013   39200000   39200000
# 20          2013   40000000   40000000
# 27          2013   40000000   40000000
# 14          2013   44000000   44000000
# 44          2013   49300000   49300000
# 23          2013   50000000   50000000
# 1           2013   55000000   55000000
# 26          2013   55000000   55000000
# 37          2013   56000000   56000000
# 40          2013   58000000   58000000
# 43          2013   60000000   60000000
# 35          2013   60000000   60000000
# 3           2013   70000000   70000000
# 34          2013   70000000   70000000
# 5           2013   75000000   75000000
# 16          2013   90000000   90000000
# 38          2013   90000000   90000000
# 41          2013  100000000  100000000
# 31          2013  100000000  100000000
# 36          2013  103000000  103000000
# 18          2013  105000000  105000000
# 32          2013  105000000  105000000
# 4           2013  115000000  115000000
# 30          2013  120000000  120000000
# 24          2013  130000000  130000000
# 45          2013  150000000  150000000
# 12          2013  195000000  195000000
# 10          2013  200000000  200000000
# 39          2013  225000000  225000000
# 8           2013  250000000  250000000

# %%
high_bud_2013
# Out:
#       id                              belongs_to_collection   budget_x  \
# 15  1138                                                NaN   22000000
# 42  2816                                                NaN   25000000
# 11   913                                                NaN   25000000
# 17  1202                                                NaN   25000000
# 25  1559                                                NaN   27220000
# 33  2060                                                NaN   28000000
# 29  1930                                                NaN   28000000
# 6    413                                                NaN   28000000
# 9    677  [{'id': 179892, 'name': 'Kick-Ass Collection',...   28000000
# 28  1884  [{'id': 454520, 'name': 'Captain Harlock Colle...   30000000
# 21  1406                                                NaN   30000000
# 22  1423                                                NaN   32000000
# 2    216                                                NaN   35000000
# 7    600                                                NaN   35000000
# 19  1301                                                NaN   35000000
# 13   985                                                NaN   35000000
# 0    148                                                NaN   39200000
# 20  1346                                                NaN   40000000
# 27  1880                                                NaN   40000000
# 14  1124                                                NaN   44000000
# 44  2857                                                NaN   49300000
# 23  1467                                                NaN   50000000
# 1    203                                                NaN   55000000
# 26  1797                                                NaN   55000000
# 37  2263                                                NaN   56000000
# 40  2455                                                NaN   58000000
# 43  2844                                                NaN   60000000
# 35  2140                                                NaN   60000000
# 3    242                                                NaN   70000000
# 34  2122  [{'id': 386534, 'name': '... Has Fallen Collec...   70000000
# 5    337  [{'id': 382685, 'name': 'Now You See Me Collec...   75000000
# 16  1159  [{'id': 179919, 'name': 'Percy Jackson Collect...   90000000
# 38  2297                                                NaN   90000000
# 41  2460                                                NaN  100000000
# 31  2015                                                NaN  100000000
# 36  2168  [{'id': 86119, 'name': 'The Hangover Collectio...  103000000
# 18  1244                                                NaN  105000000
# 32  2059  [{'id': 134897, 'name': 'The Smurfs (Theatrica...  105000000
# 4    318                                                NaN  115000000
# 30  1973  [{'id': 453993, 'name': 'The Wolverine Collect...  120000000
# 24  1522                                                NaN  130000000
# 45  2881                                                NaN  150000000
# 12   928                                                NaN  195000000
# 10   764  [{'id': 416468, 'name': 'World War Z Collectio...  200000000
# 39  2358  [{'id': 209131, 'name': 'Man of Steel Collecti...  225000000
# 8    667  [{'id': 121938, 'name': 'The Hobbit Collection...  250000000
#
#                                                genres  \
# 15  [{'id': 53, 'name': 'Thriller'}, {'id': 18, 'n...
# 42  [{'id': 53, 'name': 'Thriller'}, {'id': 80, 'n...
# 11  [{'id': 28, 'name': 'Action'}, {'id': 18, 'nam...
# 17  [{'id': 53, 'name': 'Thriller'}, {'id': 80, 'n...
# 25  [{'id': 53, 'name': 'Thriller'}, {'id': 80, 'n...
# 33  [{'id': 18, 'name': 'Drama'}, {'id': 53, 'name...
# 29  [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'n...
# 6                  [{'id': 10749, 'name': 'Romance'}]
# 9   [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
# 28  [{'id': 16, 'name': 'Animation'}, {'id': 878, ...
# 21  [{'id': 80, 'name': 'Crime'}, {'id': 35, 'name...
# 22  [{'id': 12, 'name': 'Adventure'}, {'id': 18, '...
# 2   [{'id': 35, 'name': 'Comedy'}, {'id': 80, 'nam...
# 7   [{'id': 53, 'name': 'Thriller'}, {'id': 18, 'n...
# 19  [{'id': 27, 'name': 'Horror'}, {'id': 35, 'nam...
# 13  [{'id': 28, 'name': 'Action'}, {'id': 80, 'nam...
# 0   [{'id': 28, 'name': 'Action'}, {'id': 878, 'na...
# 20  [{'id': 28, 'name': 'Action'}, {'id': 18, 'nam...
# 27  [{'id': 18, 'name': 'Drama'}, {'id': 80, 'name...
# 14  [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
# 44  [{'id': 16, 'name': 'Animation'}, {'id': 18, '...
# 23  [{'id': 14, 'name': 'Fantasy'}, {'id': 27, 'na...
# 1   [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 26  [{'id': 28, 'name': 'Action'}, {'id': 18, 'nam...
# 37  [{'id': 53, 'name': 'Thriller'}, {'id': 80, 'n...
# 40                     [{'id': 35, 'name': 'Comedy'}]
# 43  [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
# 35  [{'id': 80, 'name': 'Crime'}, {'id': 18, 'name...
# 3   [{'id': 16, 'name': 'Animation'}, {'id': 10402...
# 34  [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...
# 5   [{'id': 53, 'name': 'Thriller'}, {'id': 80, 'n...
# 16  [{'id': 12, 'name': 'Adventure'}, {'id': 10751...
# 38  [{'id': 12, 'name': 'Adventure'}, {'id': 35, '...
# 41  [{'id': 16, 'name': 'Animation'}, {'id': 12, '...
# 31  [{'id': 80, 'name': 'Crime'}, {'id': 18, 'name...
# 36                     [{'id': 35, 'name': 'Comedy'}]
# 18  [{'id': 878, 'name': 'Science Fiction'}, {'id'...
# 32  [{'id': 14, 'name': 'Fantasy'}, {'id': 10751, ...
# 4   [{'id': 878, 'name': 'Science Fiction'}, {'id'...
# 30  [{'id': 28, 'name': 'Action'}, {'id': 878, 'na...
# 24  [{'id': 878, 'name': 'Science Fiction'}, {'id'...
# 45  [{'id': 28, 'name': 'Action'}, {'id': 18, 'nam...
# 12  [{'id': 28, 'name': 'Action'}, {'id': 10751, '...
# 10  [{'id': 28, 'name': 'Action'}, {'id': 18, 'nam...
# 39  [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
# 8   [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
#
#                                           homepage    imdb_id  \
# 15                                             NaN  tt1206543
# 42                http://www.painandgainmovie.com/  tt1980209
# 11                                             NaN  tt2016940
# 17                                             NaN  tt2193215
# 25                                             NaN  tt2005374
# 33                                             NaN  tt1837703
# 29                                             NaN  tt2343793
# 6                                              NaN  tt1702439
# 9                                              NaN  tt1650554
# 28                                             NaN  tt2668134
# 21                                             NaN  tt2404311
# 22                                             NaN  tt2101473
# 2                http://www.identitythiefmovie.com  tt2024432
# 7                                              NaN  tt0882977
# 19                                             NaN  tt1588173
# 13                                             NaN  tt1904996
# 0                     http://snowpiercer-film.com/  tt1706620
# 20                http://www.lonesurvivorfilm.com/  tt1091191
# 27            http://www.americanhustle-movie.com/  tt1800241
# 14                                             NaN  tt1517260
# 44            http://www.kaguyahime-monogatari.jp/  tt2576852
# 23            http://www.hanselandgretelmovie.com/  tt1428538
# 1                                              NaN  tt1621039
# 26             http://www.captainphillipsmovie.com  tt1535109
# 37                 http://www.brokencitymovie.com/  tt1235522
# 40              http://www.theinternshipmovie.com/  tt2234155
# 43       http://www.themortalinstrumentsmovie.com/  tt1538403
# 35            http://gangstersquad.warnerbros.com/  tt1321870
# 3              http://www.dorothyofozthemovie.com/  tt0884726
# 34                                             NaN  tt2302755
# 5                                              NaN  tt1670345
# 16  http://www.percyjacksonthemovie.com/us/#!/home  tt1854564
# 38                                             NaN  tt0359950
# 41                                             NaN  tt0848537
# 31             http://www.thewolfofwallstreet.com/  tt0993846
# 36                                             NaN  tt1951261
# 18             http://gravitymovie.warnerbros.com/  tt1454468
# 32                         http://smurfhappens.com  tt2017020
# 4                                              NaN  tt1535108
# 30                http://www.thewolverinemovie.com  tt1430132
# 24                                             NaN  tt1815862
# 45                                             NaN  tt2334879
# 12        http://jackthegiantkiller.warnerbros.com  tt1351685
# 10                   http://www.worldwarzmovie.com  tt0816711
# 39                      http://www.manofsteel.com/  tt0770828
# 8                        http://www.thehobbit.com/  tt1170358
#
#    original_language                         original_title  \
# 15                en                     Out of the Furnace
# 42                en                            Pain & Gain
# 11                en                         Man of Tai Chi
# 17                en                          The Counselor
# 25                en                      The Frozen Ground
# 33                en                       The Fifth Estate
# 29                en                           Third Person
# 6                 en                             Safe Haven
# 9                 en                             Kick-Ass 2
# 28                ja                             キャプテンハーロック
# 21                en                             The Family
# 22                en                          The Physician
# 2                 en                         Identity Thief
# 7                 en                                 Snitch
# 19                en                            Warm Bodies
# 13                en                                 Parker
# 0                 ko                            Snowpiercer
# 20                en                          Lone Survivor
# 27                en                        American Hustle
# 14                en                               The Host
# 44                ja                                かぐや姫の物語
# 23                en         Hansel & Gretel: Witch Hunters
# 1                 en                             Free Birds
# 26                en                       Captain Phillips
# 37                en                            Broken City
# 40                en                         The Internship
# 43                en  The Mortal Instruments: City of Bones
# 35                en                         Gangster Squad
# 3                 en        Legends of Oz: Dorothy's Return
# 34                en                     Olympus Has Fallen
# 5                 en                         Now You See Me
# 16                en         Percy Jackson: Sea of Monsters
# 38                en        The Secret Life of Walter Mitty
# 41                en                                   Epic
# 31                en                The Wolf of Wall Street
# 36                en                  The Hangover Part III
# 18                en                                Gravity
# 32                en                           The Smurfs 2
# 4                 en                                Elysium
# 30                en                          The Wolverine
# 24                en                            After Earth
# 45                en                       White House Down
# 12                en                  Jack the Giant Slayer
# 10                en                            World War Z
# 39                en                           Man of Steel
# 8                 en    The Hobbit: The Desolation of Smaug
#
#                                              overview  popularity  ...  \
# 15  Two brothers live in the economically-depresse...    6.760321  ...
# 42  Daniel Lugo, manager of the Sun Gym in 1990s M...    9.218002  ...
# 11  In Beijing, a young martial artist's skill pla...   11.829231  ...
# 17  A rich and successful lawyer named Counselor i...   14.723646  ...
# 25  An Alaska State Trooper partners with a young ...   12.388833  ...
# 33  A look at the relationship between WikiLeaks f...   10.850442  ...
# 29  An acclaimed novelist struggles to write an an...    8.808328  ...
# 6   A young woman with a mysterious past lands in ...    7.598422  ...
# 9   After Kick-Ass‚Äô insane bravery inspires a ne...   13.570264  ...
# 28  Space Pirate Captain Harlock and his fearless ...    7.857666  ...
# 21  The Manzoni family, a notorious mafia clan, is...    8.047735  ...
# 22  The story of Rob Cole, a boy who is left a pen...   13.332387  ...
# 2   When a mild-mannered businessman learns his id...    7.321172  ...
# 7   Construction company owner John Matthews learn...   13.542675  ...
# 19  After a zombie becomes involved with the girlf...   10.430238  ...
# 13  A thief with a unique code of professional eth...   13.963892  ...
# 0   In a future where a failed global-warming expe...   14.131906  ...
# 20  Based on the failed June 28, 2005 mission "Ope...   10.855502  ...
# 27  A con man, Irving Rosenfeld, along with his se...   16.478036  ...
# 14  A parasitic alien soul is injected into the bo...   11.342024  ...
# 44  Found inside a shining stalk of bamboo by an o...    7.566053  ...
# 23  After getting a taste for blood as children, H...   10.337211  ...
# 1   In this irreverent, hilarious, adventurous bud...    7.713231  ...
# 26  The true story of Captain Richard Phillips and...   13.776068  ...
# 37  In a broken city rife with injustice, ex-cop B...   12.136158  ...
# 40  Two recently laid-off men in their 40s try to ...    0.393865  ...
# 43  In New York City, Clary Fray, a seemingly ordi...   14.336187  ...
# 35  Los Angeles, 1949. Ruthless, Brooklyn-born mob...    8.581558  ...
# 3   Dorothy wakes up in post-tornado Kansas, only ...    6.660309  ...
# 34  When the White House (Secret Service Code: "Ol...   10.978188  ...
# 5   An FBI agent and an Interpol detective track a...   17.852022  ...
# 16  In their quest to confront the ultimate evil, ...   10.338222  ...
# 38  A timid magazine photo manager who lives life ...    8.684892  ...
# 41  A teenager finds herself transported to a deep...   11.913405  ...
# 31  A New York stockbroker refuses to cooperate in...   16.382422  ...
# 36  This time, there's no wedding. No bachelor par...   25.085639  ...
# 18  Dr. Ryan Stone, a brilliant medical engineer o...   18.501940  ...
# 32  The evil wizard Gargamel creates a couple of m...   10.640864  ...
# 4   In the year 2159, two classes of people exist:...   15.232738  ...
# 30  Wolverine faces his ultimate nemesis - and tes...    3.918287  ...
# 24  One thousand years after cataclysmic events fo...   10.747642  ...
# 45  Capitol Policeman John Cale has just been deni...    9.920223  ...
# 12  The story of an ancient war that is reignited ...   11.606061  ...
# 10  Life for former United Nations investigator Ge...   26.114917  ...
# 39  A young boy learns that he has extraordinary p...   18.538834  ...
# 8   The Dwarves, Bilbo and Gandalf have successful...   20.644776  ...
#
#                                      spoken_languages    status  \
# 15           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 42           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 11  [{'iso_639_1': 'cn', 'name': '广州话 / 廣州話'}, {'i...  Released
# 17           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 25           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 33           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 29  [{'iso_639_1': 'it', 'name': 'Italiano'}, {'is...  Released
# 6   [{'iso_639_1': 'en', 'name': 'English'}, {'iso...  Released
# 9            [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 28               [{'iso_639_1': 'ja', 'name': '日本語'}]  Released
# 21           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 22           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 2            [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 7   [{'iso_639_1': 'en', 'name': 'English'}, {'iso...  Released
# 19           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 13           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 0   [{'iso_639_1': 'en', 'name': 'English'}, {'iso...  Released
# 20           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 27           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 14           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 44               [{'iso_639_1': 'ja', 'name': '日本語'}]  Released
# 23           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 1            [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 26  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...  Released
# 37           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 40           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 43           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 35           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 3            [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 34  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...  Released
# 5   [{'iso_639_1': 'fr', 'name': 'Français'}, {'is...  Released
# 16           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 38           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 41           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 31  [{'iso_639_1': 'fr', 'name': 'Français'}, {'is...  Released
# 36           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 18           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 32           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 4            [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 30           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 24           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 45           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 12           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 10           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 39           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 8            [{'iso_639_1': 'en', 'name': 'English'}]  Released
#
#                                               tagline  \
# 15                 Sometimes your battles choose you.
# 42         Their American dream is bigger than yours.
# 11                 No Rules. No Mercy. Pure Fighting.
# 17                                   Sin Is A Choice.
# 25                      The hunter becomes the hunted
# 33  You can't expose the world's secrets without e...
# 29             Life can change at the turn of a page.
# 6                        You know it when you find it
# 9                       You Can't Fight Your Destiny.
# 28                                                NaN
# 21  Some call it organized crime. Others call it f...
# 22                                                NaN
# 2                   She's having the time of his life
# 7              How far would you go to save your son?
# 19                             Cold body. Warm heart.
# 13         To get away clean, you have to play dirty.
# 0   AD 2031, the passengers in the train are the o...
# 20                      Based on True Acts of Courage
# 27                        Everyone Hustles To Survive
# 14                              You will be one of us
# 44                  A princess's crime and punishment
# 23                           Classic tale. New twist.
# 1                             Hang On To Your Nuggets
# 26                   Out here survival is everything.
# 37                    Proof Can Be a Powerful Weapon.
# 40               Hiring them was a brilliant mistake.
# 43                               You have been chosen
# 35                     No Names. No Badges. No Mercy.
# 3                            There's trouble in OZ...
# 34          When our flag falls our nation will rise.
# 5   4 amazing magicians. 3 impossible heists. 1 bi...
# 16          Where There Are Gods, There Are Monsters.
# 38                        Stop Dreaming, Start Living
# 41           Discover a world beyond your imagination
# 31                                EARN. SPEND. PARTY.
# 36                                       It all ends.
# 18                                       Don't Let Go
# 32                          Get ready to get naughty!
# 4                                 He can save us all.
# 30    When he's most vulnerable, he's most dangerous.
# 24                   Danger is real, fear is a choice
# 45                  It will start like any other day.
# 12                      Prepare for a giant adventure
# 10                                   Remember Philly!
# 39               You will believe that a man can fly.
# 8   Beyond darkness... beyond desolation... lies t...
#
#                                     title  \
# 15                     Out of the Furnace
# 42                            Pain & Gain
# 11                         Man of Tai Chi
# 17                          The Counselor
# 25                      The Frozen Ground
# 33                       The Fifth Estate
# 29                           Third Person
# 6                              Safe Haven
# 9                              Kick-Ass 2
# 28           Space Pirate Captain Harlock
# 21                             The Family
# 22                          The Physician
# 2                          Identity Thief
# 7                                  Snitch
# 19                            Warm Bodies
# 13                                 Parker
# 0                             Snowpiercer
# 20                          Lone Survivor
# 27                        American Hustle
# 14                               The Host
# 44        The Tale of the Princess Kaguya
# 23         Hansel & Gretel: Witch Hunters
# 1                              Free Birds
# 26                       Captain Phillips
# 37                            Broken City
# 40                         The Internship
# 43  The Mortal Instruments: City of Bones
# 35                         Gangster Squad
# 3         Legends of Oz: Dorothy's Return
# 34                     Olympus Has Fallen
# 5                          Now You See Me
# 16         Percy Jackson: Sea of Monsters
# 38        The Secret Life of Walter Mitty
# 41                                   Epic
# 31                The Wolf of Wall Street
# 36                  The Hangover Part III
# 18                                Gravity
# 32                           The Smurfs 2
# 4                                 Elysium
# 30                          The Wolverine
# 24                            After Earth
# 45                       White House Down
# 12                  Jack the Giant Slayer
# 10                            World War Z
# 39                           Man of Steel
# 8     The Hobbit: The Desolation of Smaug
#
#                                              Keywords  \
# 15  [{'id': 378, 'name': 'prison'}, {'id': 380, 'n...
# 42  [{'id': 416, 'name': 'miami'}, {'id': 11454, '...
# 11  [{'id': 478, 'name': 'china'}, {'id': 779, 'na...
# 17  [{'id': 496, 'name': 'poetry'}, {'id': 10909, ...
# 25  [{'id': 1419, 'name': 'gun'}, {'id': 10685, 'n...
# 33  [{'id': 736, 'name': 'journalist'}, {'id': 556...
# 29  [{'id': 293, 'name': 'female nudity'}, {'id': ...
# 6   [{'id': 818, 'name': 'based on novel'}, {'id':...
# 9   [{'id': 853, 'name': 'crime fighter'}, {'id': ...
# 28                                                NaN
# 21  [{'id': 254, 'name': 'france'}, {'id': 4009, '...
# 22  [{'id': 1279, 'name': 'medicine'}, {'id': 1965...
# 2                                                 NaN
# 7   [{'id': 494, 'name': 'father son relationship'...
# 19  [{'id': 4458, 'name': 'post-apocalyptic'}, {'i...
# 13  [{'id': 191604, 'name': 'professional thief'},...
# 0   [{'id': 494, 'name': 'father son relationship'...
# 20  [{'id': 6091, 'name': 'war'}, {'id': 10349, 'n...
# 27  [{'id': 10453, 'name': 'con artist'}, {'id': 1...
# 14  [{'id': 818, 'name': 'based on novel'}, {'id':...
# 44  [{'id': 7376, 'name': 'princess'}, {'id': 1844...
# 23  [{'id': 616, 'name': 'witch'}, {'id': 4252, 'n...
# 1   [{'id': 65, 'name': 'holiday'}, {'id': 4543, '...
# 26  [{'id': 3799, 'name': 'ship'}, {'id': 4245, 'n...
# 37  [{'id': 1919, 'name': 'mayor'}, {'id': 5340, '...
# 40  [{'id': 3489, 'name': 'job interview'}, {'id':...
# 43  [{'id': 290, 'name': 'angel'}, {'id': 3133, 'n...
# 35  [{'id': 12670, 'name': 'los angeles'}, {'id': ...
# 3                                                 NaN
# 34  [{'id': 833, 'name': 'white house'}, {'id': 41...
# 5   [{'id': 90, 'name': 'paris'}, {'id': 974, 'nam...
# 16  [{'id': 351, 'name': 'poison'}, {'id': 2034, '...
# 38  [{'id': 486, 'name': 'himalaya'}, {'id': 1003,...
# 41  [{'id': 2486, 'name': 'fantasy'}, {'id': 15907...
# 31  [{'id': 417, 'name': 'corruption'}, {'id': 572...
# 36  [{'id': 9663, 'name': 'sequel'}, {'id': 11461,...
# 18  [{'id': 4040, 'name': 'space mission'}, {'id':...
# 32  [{'id': 10244, 'name': 'based on cartoon'}, {'...
# 4   [{'id': 4565, 'name': 'dystopia'}, {'id': 1560...
# 30  [{'id': 233, 'name': 'japan'}, {'id': 1462, 'n...
# 24                 [{'id': 4565, 'name': 'dystopia'}]
# 45  [{'id': 840, 'name': 'usa president'}, {'id': ...
# 12  [{'id': 179411, 'name': 'based on fairy tale'}...
# 10  [{'id': 4565, 'name': 'dystopia'}, {'id': 1233...
# 39  [{'id': 83, 'name': 'saving the world'}, {'id'...
# 8   [{'id': 603, 'name': 'elves'}, {'id': 604, 'na...
#
#                                                  cast  \
# 15  [{'cast_id': 3, 'character': 'Russell Baze', '...
# 42  [{'cast_id': 6, 'character': 'Daniel Lugo', 'c...
# 11  [{'cast_id': 2, 'character': 'Donaka Mark', 'c...
# 17  [{'cast_id': 3, 'character': 'The Counselor', ...
# 25  [{'cast_id': 1, 'character': 'Jack Halcombe', ...
# 33  [{'cast_id': 1, 'character': 'Julian Assange',...
# 29  [{'cast_id': 3, 'character': 'Michael', 'credi...
# 6   [{'cast_id': 9, 'character': 'Katie Feldman', ...
# 9   [{'cast_id': 35, 'character': 'Dave Lizewski /...
# 28  [{'cast_id': 1, 'character': 'Captain Harlock ...
# 21  [{'cast_id': 5, 'character': 'Fred Blake / Gio...
# 22  [{'cast_id': 4, 'character': 'Rob Cole', 'cred...
# 2   [{'cast_id': 12, 'character': 'Sandy Patterson...
# 7   [{'cast_id': 12, 'character': 'John Matthews',...
# 19  [{'cast_id': 13, 'character': 'R', 'credit_id'...
# 13  [{'cast_id': 4, 'character': 'Parker', 'credit...
# 0   [{'cast_id': 4, 'character': 'Curtis Everett',...
# 20  [{'cast_id': 3, 'character': 'Marcus Luttrell'...
# 27  [{'cast_id': 3, 'character': 'Irving Rosenfeld...
# 14  [{'cast_id': 52, 'character': 'Melanie Stryder...
# 44  [{'cast_id': 5, 'character': 'Princess Kaguya ...
# 23  [{'cast_id': 3, 'character': 'Hansel', 'credit...
# 1   [{'cast_id': 2, 'character': 'Reggie (voice)',...
# 26  [{'cast_id': 10, 'character': 'Captain Richard...
# 37  [{'cast_id': 3, 'character': 'Billy Taggart', ...
# 40  [{'cast_id': 7, 'character': 'Nick Campbell', ...
# 43  [{'cast_id': 1, 'character': 'Clary Fray', 'cr...
# 35  [{'cast_id': 12, 'character': "John O'Mara", '...
# 3   [{'cast_id': 2, 'character': 'Dorothy (voice)'...
# 34  [{'cast_id': 7, 'character': 'Mike Banning', '...
# 5   [{'cast_id': 3, 'character': 'J. Daniel Atlas'...
# 16  [{'cast_id': 2, 'character': 'Percy Jackson', ...
# 38  [{'cast_id': 11, 'character': 'Walter Mitty', ...
# 41  [{'cast_id': 11, 'character': 'Nod (voice)', '...
# 31                                                NaN
# 36  [{'cast_id': 8, 'character': 'Phil', 'credit_i...
# 18  [{'cast_id': 3, 'character': 'Dr. Ryan Stone',...
# 32  [{'cast_id': 5, 'character': 'Gargamel', 'cred...
# 4   [{'cast_id': 3, 'character': 'Max', 'credit_id...
# 30  [{'cast_id': 37, 'character': 'Logan / Wolveri...
# 24  [{'cast_id': 11, 'character': 'Kitai Raige', '...
# 45  [{'cast_id': 9, 'character': 'Cale', 'credit_i...
# 12  [{'cast_id': 7, 'character': 'Jack', 'credit_i...
# 10  [{'cast_id': 4, 'character': 'Gerry Lane', 'cr...
# 39  [{'cast_id': 2, 'character': 'Clark Kent / Kal...
# 8   [{'cast_id': 3, 'character': 'Bilbo Baggins', ...
#
#                                                  crew    revenue release_year  \
# 15  [{'credit_id': '52fe4c7ac3a36847f82304c3', 'de...   15400000         2013
# 42  [{'credit_id': '52fe4bcdc3a368484e199d03', 'de...   86175291         2013
# 11  [{'credit_id': '52fe4941c3a368484e122211', 'de...    2054941         2013
# 17  [{'credit_id': '530038159251416ad81ef051', 'de...   71009334         2013
# 25  [{'credit_id': '52fe4d9b9251416c9111bfb5', 'de...    5496951         2013
# 33  [{'credit_id': '52fe4c60c3a36847f822b129', 'de...    8555008         2013
# 29  [{'credit_id': '52fe4c9d9251416c910fa89b', 'de...    1749201         2013
# 6   [{'credit_id': '54876e7b9251416b9400008f', 'de...   97594140         2013
# 9   [{'credit_id': '52fe499dc3a36847f81a3a51', 'de...   60700000         2013
# 28  [{'credit_id': '52fe4cac9251416c910fc711', 'de...   17137302         2013
# 21  [{'credit_id': '52fe4b11c3a36847f81f0b39', 'de...   36894225         2013
# 22  [{'credit_id': '561389fd92514147d800de96', 'de...   57284237         2013
# 2   [{'credit_id': '52fe4ab6c3a36847f81dd875', 'de...  173965010         2013
# 7   [{'credit_id': '52fe4bd0c3a368484e19a431', 'de...   42930462         2013
# 19  [{'credit_id': '52fe48649251416c9108ad23', 'de...  116980662         2013
# 13  [{'credit_id': '52fe4bfac3a36847f821ba9d', 'de...   46216641         2013
# 0   [{'credit_id': '52fe4ad6c3a36847f81e448d', 'de...   86758912         2013
# 20  [{'credit_id': '52fe4cd79251416c91101fb9', 'de...  149295601         2013
# 27  [{'credit_id': '52fe4cd3c3a36847f8240683', 'de...  251171807         2013
# 14  [{'credit_id': '52fe487bc3a368484e0fa8bd', 'de...   63327201         2013
# 44  [{'credit_id': '52fe4bf69251416c7511355b', 'de...   24186232         2013
# 23  [{'credit_id': '52fe461fc3a368484e07ff69', 'de...  224803475         2013
# 1   [{'credit_id': '52fe4d61c3a36847f825dbcf', 'de...  110000000         2013
# 26  [{'credit_id': '52fe4ab5c3a36847f81dd519', 'de...   95000000         2013
# 37  [{'credit_id': '52fe4a0f9251416c750dc54d', 'de...   19701164         2013
# 40  [{'credit_id': '52fe4b9cc3a36847f820bf9d', 'de...   44000000         2013
# 43  [{'credit_id': '52fe4a98c3a368484e15c653', 'de...   90565421         2013
# 35  [{'credit_id': '52fe48689251416c9108b7a7', 'de...  105200903         2013
# 3   [{'credit_id': '52fe49a6c3a36847f81a556b', 'de...   18662027         2013
# 34  [{'credit_id': '52fe4bafc3a36847f820f62f', 'de...  161025640         2013
# 5   [{'credit_id': '52fe490bc3a368484e117ceb', 'de...  117698894         2013
# 16  [{'credit_id': '56a01066c3a36858c800aa63', 'de...  174578751         2013
# 38  [{'credit_id': '52fe4b9dc3a36847f820c10b', 'de...  188133322         2013
# 41  [{'credit_id': '52fe4b9ac3a36847f820b847', 'de...  268426634         2013
# 31                                                NaN  392000694         2013
# 36  [{'credit_id': '52fe4ab7c3a36847f81ddbaf', 'de...  362000072         2013
# 18  [{'credit_id': '52fe4783c3a36847f8139de3', 'de...  716392705         2013
# 32  [{'credit_id': '52fe4983c3a368484e12f5a3', 'de...  347434178         2013
# 4   [{'credit_id': '52fe47a0c3a368484e0d17e7', 'de...  286140700         2013
# 30  [{'credit_id': '5612aac3c3a368681f0141ac', 'de...  415440673         2013
# 24  [{'credit_id': '52fe486f9251416c9108c631', 'de...  243843127         2013
# 45  [{'credit_id': '52fe4baec3a36847f820f3b1', 'de...  205366737         2013
# 12  [{'credit_id': '52fe47ef9251416c9107aa0f', 'de...  197687603         2013
# 10  [{'credit_id': '570bbe9ec3a3684b50000391', 'de...  531865000         2013
# 39  [{'credit_id': '52fe4799c3a36847f813e601', 'de...  662845518         2013
# 8   [{'credit_id': '5350e7b0c3a3681d93000e5d', 'de...  958400000         2013
#
#      budget_y
# 15   22000000
# 42   25000000
# 11   25000000
# 17   25000000
# 25   27220000
# 33   28000000
# 29   28000000
# 6    28000000
# 9    28000000
# 28   30000000
# 21   30000000
# 22   32000000
# 2    35000000
# 7    35000000
# 19   35000000
# 13   35000000
# 0    39200000
# 20   40000000
# 27   40000000
# 14   44000000
# 44   49300000
# 23   50000000
# 1    55000000
# 26   55000000
# 37   56000000
# 40   58000000
# 43   60000000
# 35   60000000
# 3    70000000
# 34   70000000
# 5    75000000
# 16   90000000
# 38   90000000
# 41  100000000
# 31  100000000
# 36  103000000
# 18  105000000
# 32  105000000
# 4   115000000
# 30  120000000
# 24  130000000
# 45  150000000
# 12  195000000
# 10  200000000
# 39  225000000
# 8   250000000
#
# [46 rows x 25 columns]

# %%
imdb_df[imdb_df['release_year']==2013]['release_year'].unique()
# Out:
# array([2013])

# %%
import pandas as pd
import datetime as dt

# dictionary of string as key
# and list as a value
raw_data = {'Leaders': ['Mahatma Gandhi', 'Jawaharlal Nehru',
                        'Atal Bihari Vajpayee', 'Rabindranath Tagore'],
            'birth_date': ['10-02-1869', '11-14-1889',
                           '12-25-1924', '05-07-1861']}

# create a dataframe object
df = pd.DataFrame(raw_data,
                  index = ['Mahatma Gandhi', 'Jawaharlal Nehru',
                           'Atal Bihari Vajpayee',
                           'Rabindranath Tagore'])

# %%
df
# Out:
#                                    Leaders  birth_date
# Mahatma Gandhi              Mahatma Gandhi  10-02-1869
# Jawaharlal Nehru          Jawaharlal Nehru  11-14-1889
# Atal Bihari Vajpayee  Atal Bihari Vajpayee  12-25-1924
# Rabindranath Tagore    Rabindranath Tagore  05-07-1861

# %%
# get a year from corresponding
# birth_date column value
df['birth_date_dtformat'] = pd.to_datetime(df['birth_date'])
df
# Out:
#                                    Leaders  birth_date birth_date_dtformat
# Mahatma Gandhi              Mahatma Gandhi  10-02-1869          1869-10-02
# Jawaharlal Nehru          Jawaharlal Nehru  11-14-1889          1889-11-14
# Atal Bihari Vajpayee  Atal Bihari Vajpayee  12-25-1924          1924-12-25
# Rabindranath Tagore    Rabindranath Tagore  05-07-1861          1861-05-07

# %%
df['day'] = pd.to_datetime(df['birth_date']).dt.day
df
# Out:
#                                    Leaders  birth_date birth_date_dtformat  \
# Mahatma Gandhi              Mahatma Gandhi  10-02-1869          1869-10-02
# Jawaharlal Nehru          Jawaharlal Nehru  11-14-1889          1889-11-14
# Atal Bihari Vajpayee  Atal Bihari Vajpayee  12-25-1924          1924-12-25
# Rabindranath Tagore    Rabindranath Tagore  05-07-1861          1861-05-07
#
#                       day  month  year
# Mahatma Gandhi          2     10  1869
# Jawaharlal Nehru       14     11  1889
# Atal Bihari Vajpayee   25     12  1924
# Rabindranath Tagore     7      5  1861

# %%
df['month']=pd.to_datetime(df['birth_date']).dt.month
df
# Out:
#                                    Leaders  birth_date birth_date_dtformat  \
# Mahatma Gandhi              Mahatma Gandhi  10-02-1869          1869-10-02
# Jawaharlal Nehru          Jawaharlal Nehru  11-14-1889          1889-11-14
# Atal Bihari Vajpayee  Atal Bihari Vajpayee  12-25-1924          1924-12-25
# Rabindranath Tagore    Rabindranath Tagore  05-07-1861          1861-05-07
#
#                       day  month  year
# Mahatma Gandhi          2     10  1869
# Jawaharlal Nehru       14     11  1889
# Atal Bihari Vajpayee   25     12  1924
# Rabindranath Tagore     7      5  1861

# %%
# # get a year from corresponding
# # birth_date column value
df['day'] = pd.to_datetime(df['birth_date']).dt.day
df

df['month'] = pd.to_datetime(df['birth_date']).dt.month
df

df['year'] = pd.to_datetime(df['birth_date']).dt.year
df
# Out:
#                                    Leaders  birth_date birth_date_dtformat  \
# Mahatma Gandhi              Mahatma Gandhi  10-02-1869          1869-10-02
# Jawaharlal Nehru          Jawaharlal Nehru  11-14-1889          1889-11-14
# Atal Bihari Vajpayee  Atal Bihari Vajpayee  12-25-1924          1924-12-25
# Rabindranath Tagore    Rabindranath Tagore  05-07-1861          1861-05-07
#
#                       day  month  year
# Mahatma Gandhi          2     10  1869
# Jawaharlal Nehru       14     11  1889
# Atal Bihari Vajpayee   25     12  1924
# Rabindranath Tagore     7      5  1861

# %%
df.info()
# df.isnull()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4 entries, Mahatma Gandhi to Rabindranath Tagore
# Data columns (total 6 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Leaders              4 non-null      object
#  1   birth_date           4 non-null      object
#  2   birth_date_dtformat  4 non-null      datetime64[ns]
#  3   day                  4 non-null      int64
#  4   month                4 non-null      int64
#  5   year                 4 non-null      int64
# dtypes: datetime64[ns](1), int64(3), object(2)
# memory usage: 396.0+ bytes

# %% [markdown]
# ## **Groupby Operations**

# %% [markdown]
# Have you ever played a game of Tetris? 🕹️👾 Well, groupby() is like playing Tetris with your data! Imagine that each block in Tetris is a row in your dataset, and you want to group those rows together based on a specific characteristic.
#
# 🔍 For example, let's say you have a dataset of movies, and you want to group them by genre. You can use the groupby() operation to stack all the movies with the same genre on top of each other, like Tetris blocks!
#
# Here's how it works:
#
# First, you select the column that you want to group by, such as the genre column.
# Then, you call the groupby() function on your dataframe and pass in the name of the column you want to group by.
# Finally, you can perform aggregate functions on the grouped data, such as calculating the average rating for each genre

# %% [markdown]
# 🐼💻 Group by operations in Pandas refer to the process of grouping rows in a DataFrame based on the values in one or more columns, and then applying some aggregate functions to the grouped data.
#
# 👨‍💼📊 The groupby() function in Pandas is like a manager that organizes your data into groups based on common characteristics. The output of the groupby() function is a DataFrameGroupBy object, which can be used to apply various aggregate functions such as sum(), mean(), count(), max(), min(), and many more.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
import pandas as pd

# Create a sample DataFrame
data = {
    'Category': ['A', 'B', 'A', 'B', 'A', 'B'],
    'Value': [10, 15, 20, 25, 30, 35]
}
df = pd.DataFrame(data)

df
# Out:
#   Category  Value
# 0        A     10
# 1        B     15
# 2        A     20
# 3        B     25
# 4        A     30
# 5        B     35

# %%
# Group the data by 'Category' and calculate the sum of 'Value' for each group
grouped_data = df.groupby('Category').aggregate(['sum','mean'])
# grouped_data = df.groupby('Category').aggregate(sum)
grouped_data
# Print the grouped and aggregated data
grouped_data.reset_index()
# Out:
#   Category Value
#              sum  mean
# 0        A    60  20.0
# 1        B    75  25.0

# %%
grouped_data['Value']['sum']
# Out:
# Category
# A    60
# B    75
# Name: sum, dtype: int64

# %%
df.groupby('Category')['Value'].sum().reset_index()
# Out:
#   Category  Value
# 0        A     60
# 1        B     75

# %%
# We can find the maximum movie runtime across different years
max_runtime_movies_by_date = imdb_df.groupby('release_date')['runtime'].max().reset_index()

# %%
max_runtime_movies_by_date
# Out:
#      release_date  runtime
# 0          1/1/03    120.0
# 1          1/1/04    100.0
# 2          1/1/06    132.0
# 3          1/1/07    100.0
# 4          1/1/09     78.0
# ...           ...      ...
# 2393       9/9/15    132.0
# 2394       9/9/16     97.0
# 2395       9/9/88     94.0
# 2396       9/9/91    137.0
# 2397       9/9/93    144.0
#
# [2398 rows x 2 columns]

# %%
imdb_df.groupby('release_date')['budget'] #No aggregation logic

# %%
type(pd.to_datetime(imdb_df['release_date'])[0])
# Out:
# pandas._libs.tslibs.timestamps.Timestamp

# %%
pd.to_datetime(imdb_df['release_date']).dt.year
pd.to_datetime(imdb_df['release_date']).dt.month
pd.to_datetime(imdb_df['release_date']).dt.day
pd.to_datetime(imdb_df['release_date'])
# Out:
# 0      2015-02-20
# 1      2004-08-06
# 2      2014-10-10
# 3      2012-03-09
# 4      2009-02-05
#           ...
# 2995   1994-04-22
# 2996   2013-03-28
# 2997   1996-10-11
# 2998   2004-01-16
# 2999   2011-09-22
# Name: release_date, Length: 3000, dtype: datetime64[ns]

# %%
imdb_df['release_year'] = pd.to_datetime(imdb_df['release_date']).dt.year
imdb_df[['release_year','release_date']]
# Out:
#       release_year release_date
# 0             2015      2/20/15
# 1             2004       8/6/04
# 2             2014     10/10/14
# 3             2012       3/9/12
# 4             2009       2/5/09
# ...            ...          ...
# 2995          1994      4/22/94
# 2996          2013      3/28/13
# 2997          1996     10/11/96
# 2998          2004      1/16/04
# 2999          2011      9/22/11
#
# [3000 rows x 2 columns]

# %%
# We can find the median movie runtime across different years
imdb_df.groupby('release_year')['runtime'].median().reset_index()
# Out:
#     release_year  runtime
# 0           1973    110.0
# 1           1974    115.0
# 2           1975    108.0
# 3           1976    119.0
# 4           1977    106.0
# ..           ...      ...
# 85          2068    113.0
# 86          2069    145.0
# 87          2070    124.5
# 88          2071    102.0
# 89          2072     99.5
#
# [90 rows x 2 columns]

# %%
imdb_df.groupby(['release_year','original_language'],as_index=False).agg(
    {'runtime':'mean','revenue':'sum','imdb_id':'count'}).sort_values('original_language',ascending = True)
# Out:
#      release_year original_language  runtime    revenue  imdb_id
# 212          2012                ar    98.00    1347747        1
# 318          2055                bn   125.00     536364        1
# 58           1996                cn   107.00   21890845        1
# 241          2014                cn   100.00     129115        1
# 226          2013                cn   105.00       7865        1
# ..            ...               ...      ...        ...      ...
# 50           1993                zh   109.00    6933459        1
# 225          2012                zh   126.50     117940        2
# 199          2010                zh   119.00   51723285        1
# 168          2008                zh   125.00    7400000        1
# 270          2015                zh   104.25  893584817        4
#
# [348 rows x 5 columns]
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['release_year'].plot(kind='hist', bins=20, title='release_year')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_1['runtime'].plot(kind='hist', bins=20, title='runtime')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_2['revenue'].plot(kind='hist', bins=20, title='revenue')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_3['imdb_id'].plot(kind='hist', bins=20, title='imdb_id')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_4.plot(kind='scatter', x='release_year', y='runtime', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_5.plot(kind='scatter', x='runtime', y='revenue', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_6.plot(kind='scatter', x='revenue', y='imdb_id', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Time series</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['runtime']
#   ys = series['release_year']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_7.sort_values('runtime', ascending=True)
# _plot_series(df_sorted, '')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('runtime')
# _ = plt.ylabel('release_year')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['runtime']
#   ys = series['revenue']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_8.sort_values('runtime', ascending=True)
# _plot_series(df_sorted, '')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('runtime')
# _ = plt.ylabel('revenue')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['runtime']
#   ys = series['imdb_id']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_9.sort_values('runtime', ascending=True)
# _plot_series(df_sorted, '')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('runtime')
# _ = plt.ylabel('imdb_id')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   counted = (series['runtime']
#                 .value_counts()
#               .reset_index(name='counts')
#               .rename({'index': 'runtime'}, axis=1)
#               .sort_values('runtime', ascending=True))
#   xs = counted['runtime']
#   ys = counted['counts']
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_10.sort_values('runtime', ascending=True)
# _plot_series(df_sorted, '')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('runtime')
# _ = plt.ylabel('count()')
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_11['release_year'].plot(kind='line', figsize=(8, 4), title='release_year')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_12['runtime'].plot(kind='line', figsize=(8, 4), title='runtime')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_13['revenue'].plot(kind='line', figsize=(8, 4), title='revenue')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_14['imdb_id'].plot(kind='line', figsize=(8, 4), title='imdb_id')
# plt.gca().spines[['top', 'right']].set_visible(False)

# %%
 # Group the data frame by year and item and extract a number of stats from each group
imdb_df.groupby(['release_year', 'original_language'],as_index=False).agg(
    {'runtime':"mean",'revenue': "sum",'imdb_id':"count"}).sort_values(
        by='release_year').rename(
            columns ={'runtime':'avg_runtime','revenue':'total_revenue','imdb_id':'num_movies'})
# Out:
#      release_year original_language  avg_runtime  total_revenue  num_movies
# 0            1973                en   105.750000      580286683           8
# 1            1973                fr   115.000000          17808           1
# 2            1974                en   113.200000      295501369           5
# 3            1975                en   110.285714      684244588           7
# 4            1975                it     0.000000       39598448           1
# ..            ...               ...          ...            ...         ...
# 343          2070                fr   126.000000              3           1
# 344          2071                en   107.750000      276722404           8
# 346          2072                en   115.400000      290266411           5
# 345          2072                de   101.000000            100           1
# 347          2072                fr   113.500000       36601163           2
#
# [348 rows x 5 columns]

# %% [markdown]
# ## <b>Activity 4

# %% [markdown]
# Your friend is a film enthusiast and has decided to explore movies in languages other than English. He wants recommendations on which movies to watch next.
#
# Using the dataset provided, your task is to find out the language with the highest mean popularity rating and then list the top 5 movies in that language.
#
# Can you help your fellow film enthusiast friend by completing this task and providing them with recommendations for non-English movies?

# %%
# Try out here!!
reco_movies = imdb_df.groupby('original_language')['popularity'].mean().reset_index()
reco_movies.sort_values('popularity', ascending=False, inplace=True)

# %%
imdb_df[imdb_df['original_language']=='no'].sort_values('popularity', ascending=False)
# Out:
#         id                              belongs_to_collection  budget  \
# 2276  2277  [{'id': 286038, 'name': 'Dead Snow Collection'...       0
# 1075  1076  [{'id': 286038, 'name': 'Dead Snow Collection'...  800000
#
#                                                  genres  \
# 2276  [{'id': 27, 'name': 'Horror'}, {'id': 28, 'nam...
# 1075  [{'id': 27, 'name': 'Horror'}, {'id': 35, 'nam...
#
#                       homepage    imdb_id original_language original_title  \
# 2276  http://www.deadsnow.com/  tt2832470                no      Død Snø 2
# 1075   http://www.deadsnow.com  tt1278340                no        Død snø
#
#                                                overview  popularity  ...  \
# 2276  The gruesome Nazi Zombies are back to finish t...   10.287127  ...
# 1075  Eight medical students on a ski trip to Norway...    7.974726  ...
#
#      runtime                                   spoken_languages    status  \
# 2276   100.0  [{'iso_639_1': 'de', 'name': 'Deutsch'}, {'iso...  Released
# 1075    91.0             [{'iso_639_1': 'no', 'name': 'Norsk'}]  Released
#
#                       tagline                      title  \
# 2276  Heads up. They're back.  Dead Snow 2: Red vs. Dead
# 1075         Eins, Zwei, Die!                  Dead Snow
#
#                                                Keywords  \
# 2276  [{'id': 2652, 'name': 'nazis'}, {'id': 9663, '...
# 1075  [{'id': 1191, 'name': 'norway'}, {'id': 10327,...
#
#                                                    cast  \
# 2276  [{'cast_id': 19, 'character': 'Martin', 'credi...
# 1075  [{'cast_id': 1, 'character': 'Hanna', 'credit_...
#
#                                                    crew  revenue release_year
# 2276  [{'credit_id': '52fe4ebfc3a36847f82a57f3', 'de...    37473         2014
# 1075  [{'credit_id': '52fe45f69251416c75068613', 'de...  1984662         2009
#
# [2 rows x 24 columns]

# %% [markdown]
# # **✅ Summary ✅**

# %% [markdown]
# 🎓 What did you learn?
#
# 🧐 Understanding Different Data Formats and Their Characteristics:
#
# We learned that data formats can be structured or unstructured, and that structured data is typically organized in a tabular format with rows and columns. Unstructured data, on the other hand, can be in any format and requires specialized techniques for wrangling.
#
#
# 🛠️ Techniques for Data Wrangling on Structured Data:
#
#  We learned that techniques for structured data wrangling include cleaning up missing data, transforming data into a useful format, and filtering data to focus on specific insights.
#
# 🤔 Strategies for Data Wrangling on Unstructured Data:
#
#  We learned that strategies for unstructured data wrangling include using natural language processing techniques, identifying key features, and converting data into a structured format for analysis.
#
# 📚 Common Libraries and Tools for Data Wrangling on Different Data Formats:
#
#  We learned that there are many libraries and tools available for data wrangling, including Pandas, NumPy, and Beautiful Soup.
#
# 📊 Data Wrangling on CSV, JSON, and XML Data Formats:
#
#  We learned that CSV files are structured data format that stores data in a tabular format, while JSON and XML files are unstructured data formats that use a hierarchical structure to store data.
#
# 📝 Data Wrangling on HTML and Text Data Formats:
#
#  We learned that HTML and text files are unstructured data formats that can be transformed into a structured format for analysis using techniques like web scraping and regular expressions.
#
# 🔢 Data Wrangling on Binary Data Formats:
#
#  We learned that binary data formats like images and audio require specialized techniques for wrangling, such as using image processing libraries or audio processing software.
#
# 🤓 Advanced Techniques for Data Wrangling on Different Data Formats:
#
#  We learned that advanced techniques for data wrangling include using machine learning algorithms for data imputation, handling missing data, and other complex tasks.
#
# 👨‍💻 With this knowledge, you are well-equipped to start wrangling data in different formats and turning it into valuable insights!

# %% [markdown]
# # **➕ Additional Reading ➕**

# %% [markdown]
# 👋 Once upon a time, there was a data analytics company called DataIngen. They helped businesses across various industries make sense of their data through effective data-wrangling techniques. Let's take a look at their journey and how they tackled different data formats using lessson:
#
#
# 📊 Understanding Different Data Formats and Their Characteristics:
#
# DataIngen realized that different data formats have different characteristics and require different wrangling approaches. They learned that structured data is typically organized in a tabular format with rows and columns, while unstructured data can be in any format and requires specialized techniques for wrangling. 🧐
#
# 🛠️ Techniques for Data Wrangling on Structured Data:
#
# For structured data, DataIngen used techniques such as cleaning up missing data, transforming data into a useful format, and filtering data to focus on specific insights. 🧹📊🔍
#
#
# 🤔 Strategies for Data Wrangling on Unstructured Data:
#
# DataIngen tackled unstructured data by using strategies such as natural language processing techniques, identifying key features, and converting data into a structured format for analysis. 🧹📝🔍
#
# 📚 Common Libraries and Tools for Data Wrangling on Different Data Formats:
#
# DataIngen relied on many libraries and tools to wrangle data, including Pandas, NumPy, and Beautiful Soup. They also kept up-to-date with the latest data wrangling trends and techniques to stay ahead. 📚
#
# 📊 Data Wrangling on CSV, JSON, and XML Data Formats:
#
# DataIngen was experienced in wrangling data in popular formats like CSV, JSON, and XML. They understood that CSV files are structured data formats that store data in a tabular format, while JSON and XML files are unstructured data formats that use a hierarchical structure to store data. 📊
#
# 📝 Data Wrangling on HTML and Text Data Formats:
#
# DataIngen knew how to wrangle unstructured data formats like HTML and text files by using techniques such as web scraping and regular expressions. They also converted these formats into structured formats for easier analysis. 📝
#
# 🔢 Data Wrangling on Binary Data Formats:
#
# DataIngen had the expertise to wrangle binary data formats like images and audio by using specialized techniques such as image processing libraries or audio processing software. 🔢
#
#
# 🤓 Advanced Techniques for Data Wrangling on Different Data Formats:
#
# Finally, DataIngen was experienced in using advanced techniques for data wrangling, such as machine learning algorithms for data imputation, handling missing data, and other complex tasks. 🤓
# Ultimately, DataIngen helped many businesses transform their messy data into valuable insights that drove decision-making and helped them stay competitive in their industries.

# %% [markdown]
# ### **Best Practices/Tips**

# %% [markdown]
# 📊 Understanding Different Data Formats and Their Characteristics:
#
# To effectively wrangle data in different formats, it's important to understand the characteristics of each format. Structured data is typically organized in a tabular format with rows and columns, while unstructured data can be in any format and requires specialized techniques for wrangling. 🧐
#
# 🛠️ Techniques for Data Wrangling on Structured Data:When wrangling structured data, some best practices include:
#
# 🧹 Cleaning up missing or incorrect data: Use the 🧹 emoji to represent this step.
#
# 📊 Transforming the data into a useful format:Use the 📊 emoji to represent this step.
#
# 🔍 Filtering the data to focus on specific insights: Use the 🔍 emoji to represent this step.
#
# 🤔 Strategies for Data Wrangling on Unstructured Data:When wrangling unstructured data, some best practices include:
#
# 🧹 Cleaning up missing or incorrect data: Use the 🧹 emoji to represent this step.
#
# 📝 Standardizing the data to ensure consistency: Use the 📝 emoji to represent this step.
#
# 🔍 Filtering the data to focus on specific insight:Use the 🔍 emoji to represent this step.
#
#  📚 Common Libraries and Tools for Data Wrangling on Different Data Formats:
#
#
# To save time and increase efficiency, it's important to use common libraries and tools for data wrangling. Some popular libraries and tools include Pandas, NumPy, and Beautiful Soup. 📚
#
# 📊 Data Wrangling on CSV, JSON, and XML Data Formats: To effectively wrangle data in popular formats like CSV, JSON, and XML, some best practices include:
#
# 📝 Understanding the data structure: Use the 📝 emoji to represent this step.
#
# 🔍 Filtering the data to focus on specific insights: Use the 🔍 emoji to represent this step.
#
# 📊 Transforming the data into a useful format: Use the 📊 emoji to represent this step.
#
# 📝 Data Wrangling on HTML and Text Data Formats: When wrangling data in HTML and text formats, some best practices include:
#
# 🧹 Cleaning up missing or incorrect data: Use the 🧹 emoji to represent this step.
#
# 📝 Identifying key features: Use the 📝 emoji to represent this step.
#
# 📊 Transforming the data into a useful format: Use the 📊 emoji to represent this step.
#
# 🔢 Data Wrangling on Binary Data Formats:To wrangle data in binary formats like images and audio, some best practices include:
#
# 📝 Understanding the data structure: Use the 📝 emoji to represent this step.
#
# 🔍 Filtering the data to focus on specific insights: Use the 🔍 emoji to represent this step.
#
# 📊 Transforming the data into a useful format:
#
# Use the 📊 emoji to represent this step.
#
# 🤓 Advanced Techniques for Data Wrangling on Different Data Formats:
#
#
# Finally, when using advanced techniques for data wrangling, some best practices include:
#
# 📝 Understanding the limitations and potential biases of the technique: Use the 📝 emoji to represent this step.
#
# 🧹 Cleaning up missing or incorrect data: Use the 🧹 emoji to represent this step.
#
# 📊 Transforming the data into a useful format:
#
# Use the 📊 emoji to represent this step.
#
# By following these best practices and tips, you can efficiently and effectively wrangle data in different formats and turn it into valuable insights for your business or organization.
