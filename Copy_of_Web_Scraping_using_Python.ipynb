# %% [markdown]
# <a href="https://colab.research.google.com/github/sadashish2002/Data_Wrangling_Using_Python_Library/blob/main/Copy_of_Web_Scraping_using_Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **👨🏻‍🎓 Learning Objective 👨🏻‍🎓**

# %% [markdown]
# ###**Introduction**

# %% [markdown]
# 🤖 First, let's define web scraping. It's the process of extracting data from websites. Web scraping can be done manually, but writing a program to automate the process is much more efficient. 🤖
#
# 🌟 One example of how web scraping can be used is in the field of market research. Let's say you're starting a new e-commerce business and want to discover what products are popular among your potential customers. You could manually search for products on different websites and make a list, which would be time-consuming and inefficient. 🛍️👀
#
# 🌟 Instead, you can write a Python program using libraries like BeautifulSoup or Scrapy to scrape product information from popular e-commerce websites. For example, you could scrape data such as the product name, price, customer reviews, and ratings. 📈💰
#
# 🌟 This data can then be used to analyze trends in the market and identify popular products among your potential customers. You can use this information to inform your own product offerings and pricing strategies. 💡🤑
#
# 🌟 However, it's important to remember that web scraping has legal and ethical considerations. Some websites may have policies against web scraping, so make sure to read a website's terms of service before scraping their data. Additionally, be mindful of how you use the data you collect and respect people's privacy. 📖👀
#
# 🌟 In conclusion, web scraping using Python can be a powerful tool for market research and other applications. However, it's important to use it responsibly and be aware of the legal and ethical considerations. Happy scraping! 😊🌟

# %% [markdown]
# ###**Primary Goals**

# %% [markdown]
# Web scraping aims to extract data from websites, automate data collection, and analyze the extracted data. 🤖
#
# 🌟 To achieve these goals, we need to start with an introduction to web scraping and importing libraries like BeautifulSoup and Scrapy. These libraries provide the tools we need to extract data from websites. 📚
#
# 🌟 Next, we need to understand the importance of Requests. This library lets us send HTTP requests to websites and retrieve their HTML content. This is a crucial step in the web scraping process, enabling us to access the data we need. 🔍
#
# 🌟 Finally, we need to learn how to extract data from HTML. HTML is the language used to create websites containing the data we're interested in. BeautifulSoup and Scrapy allow us to navigate the HTML and extract the needed data, such as text, links, images, and more. 🌟
#
# 🌟 Let's take a real-world example. Suppose you're running a digital marketing campaign and want to analyze your competitor's websites to see their keywords. You could manually search through their websites and make a list of keywords, but that would be time-consuming and inefficient. 🔍👀
#
# 🌟 Instead, you can use web scraping with Python to extract the keywords from your competitors' websites automatically. You can use libraries like BeautifulSoup or Scrapy to extract the HTML content of their website and then search for keywords within that content. This information can then be used to optimize your own digital marketing campaign. 📈💻

# %% [markdown]
# # **📖 Learning Material 📖**

# %% [markdown]
# ![web scraping.gif](data:image/gif;base64,...)

# %% [markdown]
# ## **Introduction**

# %% [markdown]
# 🕸️🐍📊🔍 Web scraping is the process of extracting data from websites using code, and Python is a popular language for web scraping due to its simplicity, versatility, and the availability of many useful libraries. Web scraping is a powerful technique that can provide valuable insights and automate data collection tasks.
#
# 💻📈📊📉 To perform web scraping in Python, we need to first identify the target website and analyze its structure to understand how to extract the desired information. We can then use Python libraries like **Beautiful Soup, Scrapy, and Selenium** to parse and extract the relevant data from the **HTML or XML** code of the website. We can also use tools like Requests and urllib to make HTTP requests and retrieve the website's content.
#
# ⚠️🚫🤔 However, it's important to note that web scraping can sometimes be illegal or unethical if done without the website owner's permission or if it violates the website's terms of service. It's always recommended to consult legal and ethical guidelines before starting any web scraping project.
#
# In summary, web scraping using Python is a powerful technique for extracting data from websites, and it requires identifying the target website, analyzing its structure, and using Python libraries to parse and extract the relevant data. However, it's crucial to always consider the legality and ethics of web scraping and to consult relevant guidelines before starting any project. 🌐💻🔍

# %% [markdown]
# When it comes to web scraping, there are two main methods for accessing data: parsing HTML and using APIs. Parsing HTML involves extracting data directly from a website's HTML code, while using APIs involves accessing a website's data through its application programming interface (API).

# %% [markdown]
# Parsing HTML can be simpler and more straightforward than using APIs, but it may be less reliable as website layouts and HTML structures can change over time. Using APIs can provide more stable and structured data, but it may require more technical expertise and may be subject to limitations or restrictions imposed by the website owner. This is something we will look into later on.

# %% [markdown]
# When choosing a tool for web scraping, it's important to consider the complexity of the scraping task, the size and structure of the data you want to extract, and any limitations or restrictions imposed by the website owner. In general, simpler tasks can be handled by libraries like BeautifulSoup, while more complex tasks may require a tool like Scrapy or Selenium.

# %% [markdown]
# ##<b>Understanding HTML Structure

# %% [markdown]
# In order to effectively scrape data from a website, it's important to understand its HTML structure. Here are some key concepts to keep in mind:

# %% [markdown]
# ###**1. HTML tags and attributes**:

# %% [markdown]
#  HTML is the language used to create websites, and it consists of a series of tags and attributes that define the structure and content of a webpage. Tags are used to create elements such as headings, paragraphs, and images, while attributes provide additional information about these elements, such as their size, color, or position on the page.

# %% [markdown]
# * ```<h1>``` - This is a tag used to create a heading on a webpage. The number after the 'h' indicates the level of the heading (e.g. ```<h1>``` is the highest level heading).
# * ```<p>``` - This is a tag used to create a paragraph on a webpage.
# * ```<img src="image.jpg" alt="description">``` - This is a tag used to insert an image on a webpage. The 'src' attribute specifies the location of the image file, while the 'alt' attribute provides a description of the image for users who cannot see it.
#
# * ```<a href="https://example.com">link</a>``` - This is a tag used to create a hyperlink on a webpage. The 'href' attribute specifies the URL that the link should point to.
#
# * ```<div>``` - This is a tag used to create a container on a webpage. It can be used to group related elements together and apply styles or formatting to them.
# * ```<table>``` - This is a tag used to create a table on a webpage. It can contain ```<tr>``` (table row) and * ```<td>``` (table data) tags to create rows and cells within the table.
# * ```<form action="submit.php" method="post">``` - This is a tag used to create a form on a webpage. The 'action' attribute specifies the URL that the form should be submitted to, while the 'method' attribute specifies the HTTP method to use (e.g. 'post' or 'get').
# * ```<input type="text" name="username">``` - This is a tag used to create an input field on a webpage. The 'type' attribute specifies the type of input (e.g. 'text' or 'password'), while the 'name' attribute specifies the name of the input field that will be submitted when the form is submitted.
#
# These are just a few examples of the many HTML tags and attributes that can be used to create and format content on a webpage.

# %% [markdown]
# ###**2. Identifying elements to scrape**:

# %% [markdown]
# When scraping a website, it's important to identify the specific elements you want to extract. This can include text, images, links, or any other content that is relevant to your scraping task. You can use tools like BeautifulSoup or Scrapy to locate these elements in the website's HTML code.

# %% [markdown]
# * **Text**: To scrape text from a webpage, you can identify the HTML tags that contain the text you want to extract. For example, if you want to scrape the product names from an e-commerce website, you might look for ```<h2>``` tags that contain the product names. You can use BeautifulSoup or Scrapy to locate these tags and extract the text within them.
#
# * **Images**: To scrape images from a webpage, you can identify the HTML tags that contain the image URLs. For example, if you want to scrape the product images from an e-commerce website, you might look for ```<img>``` tags that contain the image URLs. You can use BeautifulSoup or Scrapy to locate these tags and extract the 'src' attribute, which contains the image URL.
#
# * **Links**: To scrape links from a webpage, you can identify the HTML tags that contain the link URLs. For example, if you want to scrape the links to product pages on an e-commerce website, you might look for ```<a>``` tags that contain the product URLs. You can use BeautifulSoup or Scrapy to locate these tags and extract the 'href' attribute, which contains the link URL.
#
# * **Tables**: To scrape data from a table on a webpage, you can identify the HTML tags that contain the table rows and cells. For example, if you want to scrape the prices and ratings of products from an e-commerce website, you might look for ```<table>``` tags that contain ```<tr>``` (table row) and ```<td>``` (table data) tags. You can use BeautifulSoup or Scrapy to locate these tags and extract the text within them.
#
# By identifying the specific elements you want to scrape and using tools like BeautifulSoup or Scrapy to locate them in the website's HTML code, you can more effectively extract the data you need for your scraping task.

# %% [markdown]
# ### **3.Inspecting HTML code:**

# %% [markdown]
#   To effectively identify elements to scrape, it's helpful to know how to inspect a website's HTML code using a browser's developer tools. Most browsers have a built-in tool that allows you to view and manipulate the HTML and CSS code of a webpage. This tool can be used to identify specific elements and attributes, and to test out different scraping methods before implementing them in your code.

# %% [markdown]
# * **Using Chrome Developer Tools**: To inspect the HTML code of a webpage using Google Chrome, you can right-click on any element on the page and select "Inspect". This will open the Chrome Developer Tools window, which displays the HTML and CSS code for the selected element. You can navigate through the code to find the elements you want to scrape, and hover over different elements to highlight them on the page.
#
# * **Using Firefox Developer Tools**: To inspect the HTML code of a webpage using Mozilla Firefox, you can right-click on any element on the page and select "Inspect Element". This will open the Firefox Developer Tools window, which displays the HTML and CSS code for the selected element. You can navigate through the code to find the elements you want to scrape, and hover over different elements to highlight them on the page.
#
# * **Identifying elements and attributes**: Once you have the developer tools open, you can use them to identify specific elements and attributes on the page. For example, you might look for tags like ```<h1>``` or ```<div>``` to locate headings or content sections. You can also inspect attributes like 'class' or 'id' to identify specific elements with unique styling or functionality.
#
#
#
#
# * **Testing scraping methods**: You can use the developer tools to test out different scraping methods before implementing them in your code. For example, you can use JavaScript commands like document.querySelectorAll() to test out CSS selectors and identify elements on the page. You can also use the console to test out regular expressions and other methods for parsing and manipulating the HTML code.
#
# By becoming familiar with a browser's developer tools, you can more effectively identify elements to scrape and test out different scraping methods before implementing them in your code.

# %% [markdown]
# ##<b>Recipe for a Beautiful Soup 🍛🍛🍛

# %% [markdown]
# Beautiful Soup provides a simple and intuitive way to navigate, search, and modify the parse tree generated by a parser such as lxml or html5lib. It can be used to extract data from HTML and XML documents, as well as to parse and manipulate the data. Beautiful Soup also supports advanced features such as working with HTML entities, encoding detection, and parsing XML documents with namespaces.

# %% [markdown]
# To use Beautiful Soup, you need to install it first. You can do this using pip, which is a package manager for Python. Open a command prompt or terminal and type:
#
# Copy

# %%
from bs4 import BeautifulSoup

# %%
# !pip install beautifulsoup4

# %% [markdown]
# Once installed, you can start using Beautiful Soup to parse and extract data from HTML or XML documents. Here's a simple example to get you started:

# %% [markdown]
# In following example, we import the BeautifulSoup class from the bs4 module. We then define a string variable that contains an HTML document, which we will parse using Beautiful Soup.
#
# To create a BeautifulSoup object, we pass the HTML document and a parser to the BeautifulSoup constructor. In this case, we are using the html.parser, which is a built-in parser in Python.
#
#  We then use the prettify() method to print the parsed HTML in a pretty format. This method indents the HTML to make it more readable.

# %%
from bs4 import BeautifulSoup as bs

html_doc = """
<html>
<head>
  <title>My Web Page</title>
</head>
<body>
  <h1>Welcome to my Web Page</h1>
  <p>This is some text.</p>
  <ul>
    <li>Item 1</li>
    <li>Item 2</li>
    <li>Item 3</li>
  </ul>
</body>
</html>
"""

soup = bs(html_doc, 'html.parser') #HTML format -> data retrival is easy

print(soup.prettify())
# Out:
# <html>
#  <head>
#   <title>
#    My Web Page
#   </title>
#  </head>
#  <body>
#   <h1>
#    Welcome to my Web Page
#   </h1>
#   <p>
#    This is some text.
#   </p>
#   <ul>
#    <li>
#     Item 1
#    </li>
#    <li>
#     Item 2
#    </li>
#    <li>
#     Item 3
#    </li>
#   </ul>
#  </body>
# </html>

# %% [markdown]
# As you can see, the parsed HTML is now indented and easier to read.
#
# Now let's say we want to extract the text of the h1 tag. We can do this using the find() method, which searches for the first occurrence of a tag with the given name. Here's an example:

# %%
soup
# Out:
# <html>
# <head>
# <title>My Web Page</title>
# </head>
# <body>
# <h1>Welcome to my Web Page</h1>
# <p>This is some text.</p>
# <ul>
# <li>Item 1</li>
# <li>Item 2</li>
# <li>Item 3</li>
# </ul>
# </body>
# </html>

# %%
# soup = BeautifulSoup(html_doc, 'html.parser')

h1_tag = soup.find('h1')

print(h1_tag)
print(h1_tag.text)
# Out:
# <h1>Welcome to my Web Page</h1>
# Welcome to my Web Page

# %% [markdown]
# In this example, we use the find() method to search for the h1 tag. We then access the text attribute of the tag to extract its text.

# %% [markdown]
# Next, let's say we want to extract all the items in the ul tag. We can do this using the find_all() method, which searches for all occurrences of a tag with the given name. Here's an example:

# %%
soup
# Out:
# <html>
# <head>
# <title>My Web Page</title>
# </head>
# <body>
# <h1>Welcome to my Web Page</h1>
# <p>This is some text.</p>
# <ul>
# <li>Item 1</li>
# <li>Item 2</li>
# <li>Item 3</li>
# </ul>
# </body>
# </html>

# %%
items = soup.find_all('li')
for i in items:
  print(i.text)
# Out:
# Item 1
# Item 2
# Item 3

# %%
soup = BeautifulSoup(html_doc, 'html.parser')

# ul_tag = soup.find('ul')
items = soup.find_all('li') #Find is for first occurance, find_all if all the list of occurance

print(items)
for item in items:
  print(item.text)
# Out:
# [<li>Item 1</li>, <li>Item 2</li>, <li>Item 3</li>]
# Item 1
# Item 2
# Item 3

# %% [markdown]
# In addition to searching for tags, Beautiful Soup also provides various methods for searching for tags based on their attributes. Here's an example:

# %%
html_doc = """
<html>
<head>
  <title>My Web Page</title>
</head>
<body>
  <h1>Welcome to my Web Page</h1>
  <p class="myclassname">This is some text.</p>
  <ul>
    <li class="baseclassname">Roti</li>
    <li>Chicken</li>
    <li>Paneer</li>
  </ul>
</body>
</html>
"""

soup = bs(html_doc,'html.parser')
p_tag = soup.find('p',class_='myclassname')
print(p_tag.text)

li_tag = soup.find_all('li')

for i in li_tag:
  print(i.text)
# Out:
# This is some text.
# Roti
# Chicken
# Paneer

# %%
html_doc = """
<html>
<head>
  <title>My Web Page</title>
</head>
<body>
  <h1>Welcome to my Web Page</h1>
  <p class="myclassname">This is some text.</p>
  <ul>
    <li class="baseclassname">Roti</li>
    <li>Chicken</li>
    <li>Paneer</li>
  </ul>
</body>
</html>
"""

soup = BeautifulSoup(html_doc, 'html.parser')

p_tag = soup.find('p', class_='myclassname')
li_tags = soup.find_all('li', class_='baseclassname')

print(p_tag.text)

for li in li_tags:
    print(li.text)
# Out:
# This is some text.
# Roti

# %% [markdown]
# In this example, we use the find() method to search for the p tag with the myclass class. We then use the find_all() method to search for all the li tags with the myclass class. We then print the text of both the p and li tags

# %% [markdown]
# **Conclusion:**
#
# Beautiful Soup is a powerful and flexible Python library for parsing and manipulating HTML and XML documents. It provides a simple and intuitive way to navigate and search the parse tree generated by a parser, and can be used to extract data from web pages, scrape data from websites, and more. With its rich feature set and ease of use, Beautiful Soup is an essential tool for any Python developer working with web scraping and data extraction.

# %% [markdown]
# ## **Introduction to Requests**

# %% [markdown]
# 🌐📥🐍 The Requests library is a powerful Python library used for making HTTP requests and handling responses from web servers. It's a popular choice for web scraping and can be used to retrieve web page content for further parsing and analysis. Here are some important things to know about using Requests for web scraping:

# %% [markdown]
# 1️⃣ To start using Requests, you first need to install it. You can do this using pip, the package installer for Python. Open your command prompt and run the following command:

# %%
# !pip install requests

# %% [markdown]
# 2️⃣ After installing Requests, you can start using it in your Python code. To make a GET request to a web page, you can use the get() method and pass in the URL of the page you want to retrieve:

# %%
import requests
url = 'https://www.example.com'
response = requests.get(url)

# %% [markdown]
# 3️⃣ The get() method returns a Response object, which contains the server's response to the request. You can access the content of the response using the text attribute, which returns the HTML content of the page:

# %%
html_content = response.text
html_content
# Out:
# '<!doctype html>\n<html>\n<head>\n    <title>Example Domain</title>\n\n    <meta charset="utf-8" />\n    <meta http-equiv="Content-type" content="text/html; charset=utf-8" />\n    <meta name="viewport" content="width=device-width, initial-scale=1" />\n    <style type="text/css">\n    body {\n        background-color: #f0f0f2;\n        margin: 0;\n        padding: 0;\n        font-family: -apple-system, system-ui, BlinkMacSystemFont, "Segoe UI", "Open Sans", "Helvetica Neue", Helvetica, Arial, sans-serif;\n        \n    }\n    div {\n        width: 600px;\n        margin: 5em auto;\n        padding: 2em;\n        background-color: #fdfdff;\n        border-radius: 0.5em;\n        box-shadow: 2px 3px 7px 2px rgba(0,0,0,0.02);\n    }\n    a:link, a:visited {\n        color: #38488f;\n        text-decoration: none;\n    }\n    @media (max-width: 700px) {\n        div {\n            margin: 0 auto;\n            width: auto;\n        }\n    }\n    </style>    \n</head>\n\n<body>\n<div>\n   
# ...

# %% [markdown]
# 4️⃣ You can also pass additional parameters to the get() method to customize your request, such as headers or query parameters. For example, to pass query parameters in the URL:

# %%
params = {'keywords': 'Data Science', 'txtLocation': 'value2'}
response = requests.get(url, params=params)
c=response.text
c
# Out:
# '<!doctype html>\n<html>\n<head>\n    <title>Example Domain</title>\n\n    <meta charset="utf-8" />\n    <meta http-equiv="Content-type" content="text/html; charset=utf-8" />\n    <meta name="viewport" content="width=device-width, initial-scale=1" />\n    <style type="text/css">\n    body {\n        background-color: #f0f0f2;\n        margin: 0;\n        padding: 0;\n        font-family: -apple-system, system-ui, BlinkMacSystemFont, "Segoe UI", "Open Sans", "Helvetica Neue", Helvetica, Arial, sans-serif;\n        \n    }\n    div {\n        width: 600px;\n        margin: 5em auto;\n        padding: 2em;\n        background-color: #fdfdff;\n        border-radius: 0.5em;\n        box-shadow: 2px 3px 7px 2px rgba(0,0,0,0.02);\n    }\n    a:link, a:visited {\n        color: #38488f;\n        text-decoration: none;\n    }\n    @media (max-width: 700px) {\n        div {\n            margin: 0 auto;\n            width: auto;\n        }\n    }\n    </style>    \n</head>\n\n<body>\n<div>\n   
# ...

# %% [markdown]
# 5️⃣ Requests also provides a convenient way to handle common authentication methods, such as Basic Authentication or OAuth. For example, to use Basic Authentication:

# %%
auth = ('username', 'password')

response = requests.get(url, auth=auth)
r =response.text
r
# Out:
# '<!doctype html>\n<html>\n<head>\n    <title>Example Domain</title>\n\n    <meta charset="utf-8" />\n    <meta http-equiv="Content-type" content="text/html; charset=utf-8" />\n    <meta name="viewport" content="width=device-width, initial-scale=1" />\n    <style type="text/css">\n    body {\n        background-color: #f0f0f2;\n        margin: 0;\n        padding: 0;\n        font-family: -apple-system, system-ui, BlinkMacSystemFont, "Segoe UI", "Open Sans", "Helvetica Neue", Helvetica, Arial, sans-serif;\n        \n    }\n    div {\n        width: 600px;\n        margin: 5em auto;\n        padding: 2em;\n        background-color: #fdfdff;\n        border-radius: 0.5em;\n        box-shadow: 2px 3px 7px 2px rgba(0,0,0,0.02);\n    }\n    a:link, a:visited {\n        color: #38488f;\n        text-decoration: none;\n    }\n    @media (max-width: 700px) {\n        div {\n            margin: 0 auto;\n            width: auto;\n        }\n    }\n    </style>    \n</head>\n\n<body>\n<div>\n   
# ...

# %% [markdown]
# 6️⃣ Finally, it's important to handle errors that may occur when making HTTP requests. Requests raises exceptions for common HTTP errors, such as 404 Not Found or 500 Internal Server Error. You can handle these exceptions using a try...except block:

# %%
try:
    response = requests.get(url)
    response.raise_for_status()
except requests.exceptions.HTTPError as err:
    print(f'HTTP error occurred: {err}')
except Exception as err:
    print(f'Other error occurred: {err}')

# %% [markdown]
# In summary, the Requests library is a powerful tool for making HTTP requests and retrieving web page content. It provides a simple and easy-to-use interface for handling common HTTP request and response features, such as headers, query parameters, and authentication. When using Requests for web scraping, it's important to handle errors that may occur and to follow ethical and legal guidelines for web scraping.

# %% [markdown]
# ##<b> Activity 1

# %% [markdown]
# **Problem**:
#
# You are tasked with retrieving the list of courses offered by a university from their website. You are given the following HTML code for the university's courses page:

# %%
html_doc = """
<html>
<head>
	<title>University Courses</title>
</head>
<body>
	<h1>University Courses</h1>
	<h2>Computer Science</h2>
	<ul>
		<li>Introduction to Programming</li>
		<li>Data Structures and Algorithms</li>
		<li>Operating Systems</li>
	</ul>
	<h2>Mathematics</h2>
	<ul>
		<li>Calculus I</li>
		<li>Linear Algebra</li>
		<li>Differential Equations</li>
	</ul>
	<h2>History</h2>
	<ul>
		<li>World History I</li>
		<li>World History II</li>
		<li>US History</li>
	</ul>
</body>
</html>
"""

# %% [markdown]
# Using Beautiful Soup, write a Python program that extracts the names of all the courses offered by the university and prints them to the console.
#
# Instructions:
#
# 1. Create a new Python file and import the necessary Beautiful Soup library.
#
# 1. Open the HTML file and read its contents.
#
# 1. Parse the HTML using Beautiful Soup.
#
# 1. Find all the ul tags in the HTML.
#
# 1. Loop through each ul tag and find all the li tags within it.
#
# 1. Loop through each li tag and extract its text.
#
# 1. Print the text of each li tag to the console.

# %% [markdown]
# **Example output:**
#
# Computer Science: Introduction to Programming, Data Structures and Algorithms, Operating Systems
#
# Mathematics: Calculus I, Linear Algebra, Differential Equations
#
# History: World History I, World History II, US History

# %% [markdown]
# ###**Solution**

# %%
from bs4 import BeautifulSoup
soup = BeautifulSoup(html_doc,'html.parser')

courses = {}
courses_list = []
for h2 in soup.find_all('h2'):
  category = h2.text
  print(category)

  for ul_list in soup.find_all('ul'):
    for li_list in ul_list.find_all('li'):
      print(li_list.text)
      courses_list.append(li_list.text)
  courses[category]= courses_list
print(courses)
# Out:
# Computer Science
# Introduction to Programming
# Data Structures and Algorithms
# Operating Systems
# Calculus I
# Linear Algebra
# Differential Equations
# World History I
# World History II
# US History
# Mathematics
# Introduction to Programming
# Data Structures and Algorithms
# Operating Systems
# Calculus I
# Linear Algebra
# Differential Equations
# World History I
# World History II
# US History
# History
# Introduction to Programming
# Data Structures and Algorithms
# Operating Systems
# Calculus I
# Linear Algebra
# Differential Equations
# World History I
# World History II
# US History
# ...

# %%
from bs4 import BeautifulSoup

# Create BeautifulSoup object
soup = BeautifulSoup(html_doc, 'html.parser')

items = soup.find_all('h2')

for i in items:
  print(i.text)
# Out:
# Computer Science
# Mathematics
# History

# %%
from bs4 import BeautifulSoup

# Create BeautifulSoup object
soup = BeautifulSoup(html_doc, 'html.parser') #step 3

# Extract courses from the HTML code
courses = {} #Define a dict

# print(soup.find_all('h2')) #List

for h2 in soup.find_all('h2'):
    category = h2.text #keys
    print(category)
    # print(category)
    course_list = [] #Empty list - every iteration
    for ul_list in soup.find_all('ul'):
      for li in ul_list.find_all('li'):
        print(li.text)
    # for li in h2.find_next_sibling('ul').find_all('li'):
    #     course_list.append(li.text)
    # print(course_list)
    # courses[category] = course_list

# Print list of courses
# for category, course_list in courses.items():
#     print(f"{category}: {', '.join(course_list)}")
# Out:
# Computer Science
# Introduction to Programming
# Data Structures and Algorithms
# Operating Systems
# Calculus I
# Linear Algebra
# Differential Equations
# World History I
# World History II
# US History
# Mathematics
# Introduction to Programming
# Data Structures and Algorithms
# Operating Systems
# Calculus I
# Linear Algebra
# Differential Equations
# World History I
# World History II
# US History
# History
# Introduction to Programming
# Data Structures and Algorithms
# Operating Systems
# Calculus I
# Linear Algebra
# Differential Equations
# World History I
# World History II
# US History

# %% [markdown]
# ## **Activity 2**

# %% [markdown]
# **Problem:**
#
# Write a Python program to scrape the text from the Wikipedia page for "Python programming language" and display it on the console using Beautiful Soup.

# %% [markdown]
# ###**Solution:**
#
# Here's a Python program that uses Beautiful Soup to scrape the text from the Wikipedia page for "Python programming language" and display it on the console:

# %%
import requests
from bs4 import BeautifulSoup

url = "https://en.wikipedia.org/wiki/Python_(programming_language)"
response = requests.get(url)

soup = BeautifulSoup(response.content,'lxml')

paragraphs  = soup.find_all('p')
for text in paragraphs:
  print(text.get_text().strip())
  print("**********")
# Out:
# **********
# Python is a high-level, general-purpose programming language. Its design philosophy emphasizes code readability with the use of significant indentation.[31]
# **********
# Python is dynamically typed and garbage-collected. It supports multiple programming paradigms, including structured (particularly procedural), object-oriented and functional programming. It is often described as a "batteries included" language due to its comprehensive standard library.[32][33]
# **********
# Guido van Rossum began working on Python in the late 1980s as a successor to the ABC programming language and first released it in 1991 as Python 0.9.0.[34] Python 2.0 was released in 2000. Python 3.0, released in 2008, was a major revision not completely backward-compatible with earlier versions. Python 2.7.18, released in 2020, was the last release of Python 2.[35]
# **********
# Python consistently ranks as one of the most popular programming languages.[36][37][38][39]
# **********
# ...

# %% [markdown]
# This program first sends a GET request to the Wikipedia page for Python programming language and gets the HTML response. It then uses Beautiful Soup to parse the HTML response and find all the paragraphs on the page. For each paragraph, it extracts the text and displays it on the console.
#
# Note that the structure of the Wikipedia page may change over time, so you may need to update the code to match the current structure of the page. Also, be sure to comply with the terms of use of the website you are scraping, and avoid scraping large amounts of data that could cause strain on the website's servers.

# %% [markdown]
# # **✅ Summary ✅**

# %% [markdown]
# 🎓 What did you learn?
#
# 🤖 We learned that web scraping is extracting data from websites. We also discussed the primary goals of web scraping, which include automating data collection, analyzing the extracted data, and extracting data efficiently and effectively. 🤖
#
# 🌟 We also discussed the importance of importing libraries like BeautifulSoup and Scrapy. These libraries provide us with the tools to extract data from websites. 📚
#
# 🌟 Additionally, we learned about the role of Requests in web scraping. Requests is a Python library that allows us to send HTTP requests to websites and retrieve their HTML content. This is a crucial step in the web scraping process, enabling us to access the data we need. 🔍
# 🌟 Finally, we discussed the process of extracting data from HTML. HTML is the language used to create websites containing the data we're interested in. BeautifulSoup and Scrapy allow us to navigate the HTML and extract the data we need, such as text, links, images, and more. 🌟
# 🌟 Overall, we learned that web scraping using Python is a powerful tool for automating data collection and analysis. By understanding the importance of importing libraries, using Requests to access the website content, and extracting data from HTML using BeautifulSoup and Scrapy, we can achieve our primary goals of web scraping. Happy scrapping! 😊🌟

# %% [markdown]
# # **➕ Additional Reading ➕**

# %% [markdown]
# **Mnemonic**
#
#
# 👋 Hi there! Let me tell you an interactive story about a company called "Scrappers Inc." who used web scraping using Python to improve their business operations. 🌐🐍
# 👨‍💼 Meet Jack, the CEO of Scrappers Inc., a company that specializes in metal recycling. Jack realized that in order to stay competitive in the industry, he needed to find ways to optimize their operations and reduce costs. That's when he came up with the idea of using web scraping to automate data collection. 💡
# 🕸️ Jack hired a team of Python developers who were experts in web scraping using libraries like BeautifulSoup and Scrapy. The team created a program that would automatically scrape data from online marketplaces and metal recycling directories to gather information on the prices of different types of scrap metal. 📊
# 💰 By analyzing this data, Scrappers Inc. was able to optimize their pricing strategies and make better business decisions. They were able to find the best markets to sell their scrap metal and negotiate better prices with their customers. This led to increased profits and improved customer satisfaction. 🤑
# 🌟 As Scrappers Inc. continued to use web scraping, they discovered even more ways to improve their operations. They were able to automate their inventory management by scraping data from their suppliers' websites, and they even used web scraping to monitor their competitors' pricing strategies. 🕵️‍♂️
# 🌎 With the help of web scraping, Scrappers Inc. was able to expand their business globally. They used web scraping to gather data on international markets and find the best opportunities to expand their operations. They were able to establish partnerships with companies around the world and increase their revenue. 🌍
# 👏 In conclusion, web scraping using Python was a game changer for Scrappers Inc. By automating data collection and analysis, they could optimize their business operations, reduce costs, and increase profits. Happy scraping! 😊🌟

# %% [markdown]
# **Best Practices/Tips**
#
#
# 🤖 First and foremost, it's important to always read a website's terms of service before scraping their data. Some websites may prohibit web scraping or limit the amount of data you can scrape. Make sure to respect these policies to avoid legal issues. 📖👀
#
# 🌟 Next, be mindful of the frequency and volume of your web scraping. Scraping a website too frequently or in large volumes can strain its servers and lead to website downtime. It's important to pace your scraping and limit the requests you send to a website. 🔍💻
#
# 🌟 Another important tip is to use a user-agent string in your requests. A user-agent string identifies the browser or device that's making the request. By including a user-agent string in your request, you can make it appear as if the request is coming from a legitimate browser or device, which can help avoid being blocked by the website. 🕵️‍♂️🌐
#
# 🌟 When scraping data, sanitizing and validating it before using it is important. This means checking for errors, duplicates, and missing data and making sure the data is in the format you expect. This will help avoid issues down the line when using the data. ✅❌
#
# 🌟 Finally, staying up-to-date on the latest developments in web scraping and any changes to websites' terms of service is important. This will ensure that you use the most effective and efficient web scraping techniques and avoid legal issues. 📈📖
#
# 👏 In conclusion, web scraping using Python can be a powerful tool when used responsibly and with consideration for legal and ethical considerations. Following these best practices and tips ensures that your web scraping efforts are effective and efficient. Happy scraping! 😊🌟

# %% [markdown]
# **Shortcomings**
#
# 🤖 One potential shortcoming of web scraping is that it can be resource-intensive in terms of time and computing power. Scraping large amounts of data from multiple websites can take a significant amount of time, and it can also put a strain on your computer's resources. This can be mitigated by limiting the data you scrape and optimizing your scraping code. 💻⏰
#
# 🌟 Another potential shortcoming is that websites can change layout and structure, breaking your scraping code. This can require frequent updates to your code, which can be time-consuming and may require expertise in programming. This can be mitigated by regularly checking the websites you scrape and updating your code accordingly. 🕵️‍♂️🔍
#
# 🌟 A third potential shortcoming is that web scraping may not always be legal or ethical. Some websites have policies against web scraping or may prohibit it altogether. Additionally, web scraping can potentially infringe on people's privacy, especially when scraping personal information. It's important to be aware of these legal and ethical considerations and to always read a website's terms of service before scraping their data. 📖👀
#
# 🌟 Finally, web scraping can potentially introduce errors and inaccuracies into your data. This can happen when the website's data is not well-formatted, or when your scraping code contains errors. It's important to sanitize and validate the data you scrape before using it to avoid these issues. ✅❌
#
# 👏 In conclusion, while web scraping using Python can be a powerful tool for data collection and analysis, it's important to be aware of the potential shortcomings and to take steps to mitigate them. By being mindful of these considerations, you can ensure that your web scraping efforts are effective and responsible. Happy scraping! 😊🌟
